# %%
import polars as pl
import pandas as pd

# %%
COMMENTS_PATH = '/Users/martinctl/Developer/EPFL/MA1/ada/project-data/gaming_comments.parquet'
COMMENTS_PATH_GAMES = '/Users/martinctl/Developer/EPFL/MA1/ada/project-data/gaming_comments_with_games.parquet'
COMMENTS_PATH_CHANNELS = '/Users/martinctl/Developer/EPFL/MA1/ada/project-data/gaming_comments_with_channels.parquet'

gaming_channels_df = pd.read_csv('../data/youniverse/filtered/gaming_channels.tsv', sep='\t')

# videos_df = pl.read_csv('../data/youniverse/filtered/gaming_videos_with_games.tsv', separator='\t')
# comments_df = pl.read_csv('../data/youniverse/filtered/gaming_comments.tsv', separator='\t')
videos_df = pl.read_parquet('/Users/martinctl/Developer/EPFL/MA1/ada/project-data/gaming_videos_with_games.parquet')

# take a subsample  of the videos_df
# videos_df = videos_df.sample(n=1000)

videos_df
# Out:
# shape: (6_821_539, 10)
# ┌───────────┬───────────┬───────────┬───────────┬───┬──────────┬───────────┬───────────┬───────────┐
# │ title     ┆ tags      ┆ upload_da ┆ view_coun ┆ … ┆ duration ┆ channel_i ┆ display_i ┆ video_gam │
# │ ---       ┆ ---       ┆ te        ┆ t         ┆   ┆ ---      ┆ d         ┆ d         ┆ e         │
# │ str       ┆ str       ┆ ---       ┆ ---       ┆   ┆ i64      ┆ ---       ┆ ---       ┆ ---       │
# │           ┆           ┆ str       ┆ f64       ┆   ┆          ┆ str       ┆ str       ┆ str       │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪══════════╪═══════════╪═══════════╪═══════════╡
# │ lego city ┆ lego city ┆ 2016-09-2 ┆ 1253.0    ┆ … ┆ 3442     ┆ UCzWrhkg9 ┆ y5IvyZlzE ┆ lego city │
# │ lego      ┆ lego      ┆ 6         ┆           ┆   ┆          ┆ eK5I8Bm3H ┆ Ls        ┆ undercove │
# │ police1   ┆ police    ┆ 00:00:00  ┆           ┆   ┆          ┆ fV-unA    ┆           ┆ r         │
# │ hour lo…  ┆ lego cit… ┆           ┆           ┆   ┆          ┆           ┆           ┆           │
# │ lego city ┆ lego city ┆ 2016-09-2 ┆ 2311.0    ┆ … ┆ 2407     ┆ UCzWrhkg9 ┆ m1agc0qT0 ┆ lego city │
# │ police    ┆ lego      ┆ 5         ┆           ┆   ┆          ┆ eK5I8Bm3H ┆ BY        ┆ undercove │
# │ lego      ┆ police    ┆ 00:00:00  ┆           ┆   ┆          ┆ fV-unA    ┆           ┆ r         │
# │ fireman … ┆ lego cit… ┆           ┆           ┆   ┆          ┆           ┆           ┆           │
# │ lego city ┆ lego city ┆ 2016-09-2 ┆ 792.0     ┆ … ┆ 1209     ┆ UCzWrhkg9 ┆ ZGll5_wD9 ┆ lego city │
# │ police    ┆ lego city ┆ 1         ┆           ┆   ┆          ┆ eK5I8Bm3H ┆ Ys        ┆ undercove │
# │ lego      ┆ police    ┆ 00:00:00  ┆           ┆   ┆          ┆ fV-unA    ┆           ┆ r         │
# │ fireman … ┆ leg…      ┆           ┆           ┆   ┆          ┆           ┆           ┆           │
# │ lego      ┆ lego      ┆ 2016-09-2 ┆ 1.141393e ┆ … ┆ 2053     ┆ UCzWrhkg9 ┆ kYkokQgnu ┆ lego      │
# │ jurassic  ┆ jurassic  ┆ 1         ┆ 6         ┆   ┆          ┆ eK5I8Bm3H ┆ 20        ┆ jurassic  │
# │ world     ┆ world     ┆ 00:00:00  ┆           ┆   ┆          ┆ fV-unA    ┆           ┆ world     │
# │ complete  ┆ lego city ┆           ┆           ┆   ┆          ┆           ┆           ┆           │
# │ m…        ┆ …         ┆           ┆           ┆   ┆          ┆           ┆           ┆           │
# │ lego      ┆ lego      ┆ 2016-09-2 ┆ 1648.0    ┆ … ┆ 4125     ┆ UCzWrhkg9 ┆ 9EuAW3zjW ┆ spiderman │
# │ marvel    ┆ marvel    ┆ 1         ┆           ┆   ┆          ┆ eK5I8Bm3H ┆ uc        ┆           │
# │ superhero ┆ lego      ┆ 00:00:00  ┆           ┆   ┆          ┆ fV-unA    ┆           ┆           │
# │ es        ┆ marvel    ┆           ┆           ┆   ┆          ┆           ┆           ┆           │
# │ comple…   ┆ super …   ┆           ┆           ┆   ┆          ┆           ┆           ┆           │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …        ┆ …         ┆ …         ┆ …         │
# │ carrying  ┆ brawlhall ┆ 2018-09-2 ┆ 10397.0   ┆ … ┆ 558      ┆ UCrwIEEqU ┆ s6mBrPKvu ┆ brawlhall │
# │ an irl    ┆ a cosolix ┆ 6         ┆           ┆   ┆          ┆ WswVQ_L_V ┆ mc        ┆ a         │
# │ friend in ┆ ranked    ┆ 00:00:00  ┆           ┆   ┆          ┆ zfeR-Q    ┆           ┆           │
# │ rank…     ┆ coso…     ┆           ┆           ┆   ┆          ┆           ┆           ┆           │
# │ playing   ┆ brawlhall ┆ 2018-09-2 ┆ 13954.0   ┆ … ┆ 363      ┆ UCrwIEEqU ┆ qneHrPX4_ ┆ brawlhall │
# │ 2s with   ┆ a cosolix ┆ 5         ┆           ┆   ┆          ┆ WswVQ_L_V ┆ AY        ┆ a         │
# │ planet    ┆ ranked    ┆ 00:00:00  ┆           ┆   ┆          ┆ zfeR-Q    ┆           ┆           │
# │ micro     ┆ coso…     ┆           ┆           ┆   ┆          ┆           ┆           ┆           │
# │ brawlhall ┆ brawlhall ┆ 2018-09-2 ┆ 24198.0   ┆ … ┆ 713      ┆ UCrwIEEqU ┆ 4H4Oz0Rjd ┆ brawlhall │
# │ a how to  ┆ a cosolix ┆ 4         ┆           ┆   ┆          ┆ WswVQ_L_V ┆ 70        ┆ a         │
# │ play      ┆ ranked    ┆ 00:00:00  ┆           ┆   ┆          ┆ zfeR-Q    ┆           ┆           │
# │ against…  ┆ coso…     ┆           ┆           ┆   ┆          ┆           ┆           ┆           │
# │ best      ┆ brawlhall ┆ 2018-09-2 ┆ 93020.0   ┆ … ┆ 1306     ┆ UCrwIEEqU ┆ c_34mr0tX ┆ brawlhall │
# │ legends   ┆ a cosolix ┆ 3         ┆           ┆   ┆          ┆ WswVQ_L_V ┆ Dk        ┆ a         │
# │ for pro   ┆ ranked    ┆ 00:00:00  ┆           ┆   ┆          ┆ zfeR-Q    ┆           ┆           │
# │ ranked    ┆ coso…     ┆           ┆           ┆   ┆          ┆           ┆           ┆           │
# │ br…       ┆           ┆           ┆           ┆   ┆          ┆           ┆           ┆           │
# │ toxic bra ┆ brawlhall ┆ 2018-09-2 ┆ 150499.0  ┆ … ┆ 531      ┆ UCrwIEEqU ┆ 3h4UJetYJ ┆ brawlhall │
# │ wlhalla   ┆ a cosolix ┆ 1         ┆           ┆   ┆          ┆ WswVQ_L_V ┆ 14        ┆ a         │
# │ player    ┆ ranked    ┆ 00:00:00  ┆           ┆   ┆          ┆ zfeR-Q    ┆           ┆           │
# │ carrie…   ┆ coso…     ┆           ┆           ┆   ┆          ┆           ┆           ┆           │
# └───────────┴───────────┴───────────┴───────────┴───┴──────────┴───────────┴───────────┴───────────┘

# %%
games_count = videos_df.group_by('video_game').agg(pl.count('video_game').alias('count')).sort('count', descending=True)
games_count
# Out:
# shape: (1_064, 2)
# ┌─────────────────────────────────┬────────┐
# │ video_game                      ┆ count  │
# │ ---                             ┆ ---    │
# │ str                             ┆ u32    │
# ╞═════════════════════════════════╪════════╡
# │ minecraft                       ┆ 766154 │
# │ fortnite                        ┆ 377337 │
# │ call of duty                    ┆ 368658 │
# │ league of legends               ┆ 236065 │
# │ roblox                          ┆ 205762 │
# │ …                               ┆ …      │
# │ pokémon unite                   ┆ 2      │
# │ neon white                      ┆ 2      │
# │ road 96                         ┆ 1      │
# │ dr kawashimas brain training h… ┆ 1      │
# │ triangle strategy               ┆ 1      │
# └─────────────────────────────────┴────────┘

# %%
gaming_channels_df
# Out:
#                      channel_id      channel_name  subscribers  videos
# 0      UC-lHJZR3Gqxm24_Vd_AJ5Yw         PewDiePie    101000000    3956
# 1      UCJ5v_MCY6GNUBTO8-D3XoAg               WWE     48400000   43421
# 2      UCRijo3ddMTht_IHyNSNXpNQ      Dude Perfect     45800000     213
# 3      UCEdvpU2pFRCVqU6yIPyTpMQ        Marshmello     39100000     366
# 4      UCqECaJ8Gagnn7YCbPEzWH6g      Taylor Swift     35800000     172
# ...                         ...               ...          ...     ...
# 33136  UCfdiBkNZbAFuAsfiEgNcA5w    Kurojaki Kaoru        10000     107
# 33137  UC2oRkTPQk0-czP04VOYigxg      BLITZFIRE911        10000     305
# 33138  UC-njwIOSrdj_RJd4JWXMrcA    Crimson Heroes        10000     425
# 33139  UCuF-FC0MrJAgdtkFQkNcP2Q  AliceTheOreo Msp        10127      67
# 33140  UCTsxFTIUs8vFDzGccDm6i7Q            Omni H        10000     475
#
# [33141 rows x 4 columns]

# %%
# Get only the display_id and video_game columns
joined_df = videos_df.select([
    pl.col('display_id'),
    pl.col('channel_id'),
])

# Create a set of mappings from display_id to video_game
df = joined_df.to_pandas()

# merge channel id to channel name
df = df.merge(gaming_channels_df, left_on='channel_id', right_on='channel_id')

videos = pl.Series('video_id', joined_df.select(pl.col('display_id')))
display_id_to_game = dict(zip(df['display_id'], df['channel_name']))

def get_game(display_id: str):
    return display_id_to_game.get(display_id, None)

# %%
df
# Out:
#           display_id                channel_id channel_name  subscribers  \
# 0        y5IvyZlzELs  UCzWrhkg9eK5I8Bm3HfV-unA  Supertronic       314000
# 1        m1agc0qT0BY  UCzWrhkg9eK5I8Bm3HfV-unA  Supertronic       314000
# 2        ZGll5_wD9Ys  UCzWrhkg9eK5I8Bm3HfV-unA  Supertronic       314000
# 3        kYkokQgnu20  UCzWrhkg9eK5I8Bm3HfV-unA  Supertronic       314000
# 4        9EuAW3zjWuc  UCzWrhkg9eK5I8Bm3HfV-unA  Supertronic       314000
# ...              ...                       ...          ...          ...
# 6821534  s6mBrPKvumc  UCrwIEEqUWswVQ_L_VzfeR-Q      Cosolix        32962
# 6821535  qneHrPX4_AY  UCrwIEEqUWswVQ_L_VzfeR-Q      Cosolix        32962
# 6821536  4H4Oz0Rjd70  UCrwIEEqUWswVQ_L_VzfeR-Q      Cosolix        32962
# 6821537  c_34mr0tXDk  UCrwIEEqUWswVQ_L_VzfeR-Q      Cosolix        32962
# 6821538  3h4UJetYJ14  UCrwIEEqUWswVQ_L_VzfeR-Q      Cosolix        32962
#
#          videos
# 0          2398
# 1          2398
# 2          2398
# 3          2398
# 4          2398
# ...         ...
# 6821534     249
# 6821535     249
# 6821536     249
# 6821537     249
# 6821538     249
#
# [6821539 rows x 5 columns]

# %%
# import random
# import time

# random.seed(42)
# random_display_id = random.sample(list(display_id_to_game.keys()), 1_000_000)

# start = time.time()
# for display_id in random_display_id:
#     get_game(display_id)
    
# print((time.time() - start) * 2000, 's')

# %%
comments_df = pl.scan_parquet(COMMENTS_PATH)

comments_valid = comments_df.filter(pl.col('video_id').is_in(videos))

comments_channels = comments_valid.with_columns(pl.col('video_id').map_elements(get_game, return_dtype=str))

# # We can now save the comments with the channels
# comments_channels.sink_parquet(COMMENTS_PATH_CHANNELS)

# comments_game_df = (pl.scan_parquet(COMMENTS_PATH_GAMES, n_rows=100_000_000)).unique()

# %%
comments_channels_df = pl.read_parquet(COMMENTS_PATH_CHANNELS, n_rows=250_000_000)

# %%
from itertools import combinations
from tqdm import tqdm

# ! Take 30 minutes to run

def get_edges(comments):
    rows = comments.shape[0]
    
    curr_author = None
    games = set()
    edges = {}
    authors = 0
    
    # Add progress tracking variables
    last_print = 0
    print_interval = 1_000_000  # Print every million authors

    for com in tqdm(comments.iter_rows(), total=rows):
        author, game = com
        if author != curr_author:
            curr_author = author
            if len(games) > 1:
                for edge in combinations(games, 2):
                    edge = tuple(sorted(edge))
                    edges[edge] = edges.get(edge, 0) + 1
            games = set()
            authors += 1
            
            # Print progress every print_interval authors
            if authors - last_print >= print_interval:
                print(f"Authors processed: {authors:,}")
                print(f"Current edges count: {len(edges):,}")
                print(f"Top edge weight: {max(edges.values()) if edges else 0:,}")
                print("---")
                last_print = authors

        if game is None:
            continue
        games.add(game)
    
    return sorted(edges.items(), key=lambda x: x[1], reverse=True)

sorted_edges = get_edges(comments_channels_df)
sorted_edges
# Out:
#   5%|▌         | 13586323/250000000 [00:45<16:58, 232064.34it/s]
# Authors processed: 1,000,000
# Current edges count: 12,843,339
# Top edge weight: 17,801
# ---
#  11%|█         | 27095601/250000000 [01:32<16:53, 219909.19it/s]
# Authors processed: 2,000,000
# Current edges count: 18,192,925
# Top edge weight: 35,610
# ---
#  16%|█▋        | 40657783/250000000 [02:23<19:05, 182688.11it/s]
# Authors processed: 3,000,000
# Current edges count: 22,101,837
# Top edge weight: 53,538
# ---
#  22%|██▏       | 54150125/250000000 [03:20<19:45, 165148.93it/s]
# Authors processed: 4,000,000
# Current edges count: 25,155,012
# Top edge weight: 71,319
# ---
#  27%|██▋       | 67630048/250000000 [05:04<17:16, 175995.77it/s]
# Authors processed: 5,000,000
# Current edges count: 27,737,510
# Top edge weight: 89,172
# ---
#  32%|███▏      | 81138350/250000000 [06:45<19:41, 142950.89it/s]
# Authors processed: 6,000,000
# Current edges count: 29,922,320
# Top edge weight: 107,291
# ---
#  38%|███▊      | 94655418/250000000 [08:00<45:41, 56668.83it/s]
# Authors processed: 7,000,000
# Current edges count: 31,900,080
# Top edge weight: 125,384
# ---
#  43%|████▎     | 108201096/250000000 [09:40<15:37, 151209.25it/s]
# Authors processed: 8,000,000
# Current edges count: 33,655,525
#  43%|████▎     | 108248994/250000000 [09:41<21:40, 109032.14it/s]
# Top edge weight: 143,360
# ---
#  49%|████▊     | 121684490/250000000 [11:22<30:35, 69917.78it/s]
# Authors processed: 9,000,000
# Current edges count: 35,774,660
# Top edge weight: 161,100
# ---
#  54%|█████▍    | 135249648/250000000 [12:35<18:56, 100932.11it/s]
# Authors processed: 10,000,000
# Current edges count: 37,251,971
# Top edge weight: 179,051
# ---
#  59%|█████▉    | 148617127/250000000 [14:22<07:14, 233578.73it/s]
# Authors processed: 11,000,000
# Current edges count: 38,570,483
#  59%|█████▉    | 148660737/250000000 [14:22<12:47, 132072.11it/s]
# Top edge weight: 196,945
# ---
#  65%|██████▍   | 162014103/250000000 [16:04<1:49:15, 13420.81it/s]
# Authors processed: 12,000,000
# Current edges count: 39,798,212
# Top edge weight: 214,811
# ---
#  70%|███████   | 175643558/250000000 [17:34<11:58, 103535.39it/s]
# Authors processed: 13,000,000
# Current edges count: 41,044,103
# Top edge weight: 232,812
# ---
#  76%|███████▌  | 189100016/250000000 [19:24<27:28, 36937.28it/s]
# Authors processed: 14,000,000
# Current edges count: 42,115,490
#  76%|███████▌  | 189120835/250000000 [19:25<28:39, 35399.98it/s]
# Top edge weight: 250,658
# ---
#  81%|████████  | 202530971/250000000 [21:22<04:22, 181078.54it/s]
# Authors processed: 15,000,000
# Current edges count: 43,163,171
#  81%|████████  | 202585540/250000000 [21:23<06:42, 117704.77it/s]
# Top edge weight: 268,366
# ---
#  86%|████████▋ | 216084422/250000000 [22:55<04:51, 116521.51it/s]
# Authors processed: 16,000,000
# Current edges count: 44,163,470
#  86%|████████▋ | 216096879/250000000 [22:56<12:02, 46916.91it/s]
# Top edge weight: 286,493
# ---
#  92%|█████████▏| 229503276/250000000 [25:06<09:05, 37594.55it/s]
# Authors processed: 17,000,000
# Current edges count: 45,102,677
# Top edge weight: 304,396
# ---
#  97%|█████████▋| 243104878/250000000 [27:03<01:37, 70891.45it/s]
# Authors processed: 18,000,000
# Current edges count: 46,017,009
#  97%|█████████▋| 243134397/250000000 [27:04<02:16, 50284.97it/s]
# Top edge weight: 322,351
# ---
# 100%|██████████| 250000000/250000000 [28:05<00:00, 148308.53it/s]
# [(('DanTDM', 'PopularMMOs'), 331438),
#  (('Markiplier', 'jacksepticeye'), 201941),
#  (('DanTDM', 'stampylonghead'), 179555),
#  (('PopularMMOs', 'SSundee'), 166893),
#  (('DanTDM', 'SSundee'), 166667),
#  (('DanTDM', 'jacksepticeye'), 158740),
#  (('Crainer', 'SSundee'), 156871),
#  (('PewDiePie', 'jacksepticeye'), 150113),
#  (('Markiplier', 'PewDiePie'), 136643),
#  (('PopularMMOs', 'stampylonghead'), 129911),
#  (('PopularMMOs', 'jacksepticeye'), 122841),
#  (('DanTDM', 'Denis'), 119783),
#  (('iBallisticSquid', 'stampylonghead'), 116642),
#  (('Markiplier', 'The Game Theorists'), 115278),
#  (('SSundee', 'Sky Does Everything'), 113993),
#  (('DanTDM', 'PewDiePie'), 112250),
#  (('PopularMMOs', 'Preston'), 112173),
#  (('The Game Theorists', 'jacksepticeye'), 110104),
#  (('DanTDM', 'Sky Does Everything'), 107878),
#  (('PopularMMOs', 'UnspeakableGaming'), 107239),
#  (('SSundee', 'jacksepticeye'), 106548),
#  (('Ali-A', 'Lachlan'), 105469),
#  (('DanTDM', 'Markiplier'), 105106),
#  (('DanTDM', 'UnspeakableGaming'), 103855),
#  (('DanTDM', 'Thinknoodles'), 102534),
#  (('GamingWithJen', 'PopularMMOs'), 101768),
#  (('DanTDM', 'Preston'), 99103),
#  (('PewDiePie', 'Sky Does Everything'), 98168),
#  (('PewDiePie', 'The Game Theorists'), 96990),
#  (('DanTDM', 'The Game Theorists'), 95070),
#  (('Ali-A', 'DanTDM'), 92534),
#  (('DanTDM', 'iBallisticSquid'), 92160),
#  (('DanTDM', 'FGTeeV'), 92040),
#  (('GameSpot', 'IGN'), 89264),
#  (('Ali-A', 'Muselk'), 88493),
#  (('CaptainSparklez', 'Sky Does Everything'), 88322),
#  (('Lachlan', 'LazarBeam'), 87530),
#  (('Denis', 'PopularMMOs'), 87435),
#  (('Ali-A', 'PewDiePie'), 87095),
#  (('Lachlan', 'Muselk'), 85709),
#  (('LDShadowLady', 'SmallishBeans'), 84141),
#  (('UnspeakableGaming', 'UnspeakablePlays'), 83405),
#  (('PopularMMOs', 'Sky Does Everything'), 83297),
#  (('Aphmau', 'PopularMMOs'), 82781),
#  (('Preston', 'SSundee'), 81705),
#  (('Markiplier', 'PopularMMOs'), 81669),
#  (('Bajan Canadian', 'Sky Does Everything'), 79160),
#  (('Crainer', 'PopularMMOs'), 76679),
#  (('CaptainSparklez', 'PewDiePie'), 76621),
#  (('PewDiePie', 'SSundee'), 76617),
#  (('DanTDM', 'Lachlan'), 75706),
#  (('Ali-A', 'GhostNinja'), 75551),
#  (('Preston', 'UnspeakableGaming'), 75388),
#  (('LazarBeam', 'Muselk'), 74558),
#  (('Sky Does Everything', 'jacksepticeye'), 74413),
#  (('DanTDM', 'TheAtlanticCraft'), 73834),
#  (('Lachlan', 'SSundee'), 73461),
#  (('Ali-A', 'SSundee'), 73062),
#  (('Markiplier', 'Sky Does Everything'), 73038),
#  (('Ali-A', 'LazarBeam'), 72757),
#  (('Aphmau', 'DanTDM'), 72575),
#  (('Bajan Canadian', 'JeromeASF'), 72454),
#  (('LDShadowLady', 'PopularMMOs'), 72161),
#  (('DanTDM', 'iHasCupquake'), 72109),
#  (('Bajan Canadian', 'SSundee'), 72073),
#  (('PewDiePie', 'PopularMMOs'), 71915),
#  (('JeromeASF', 'Sky Does Everything'), 71869),
#  (('Crainer', 'DanTDM'), 71863),
#  (('InquisitorMaster', 'ItsFunneh'), 71674),
#  (('DanTDM', 'Grian'), 71524),
#  (('CaptainSparklez', 'SSundee'), 71134),
#  (('JeromeASF', 'SSundee'), 70330),
#  (('PopularMMOs', 'The Game Theorists'), 69668),
#  (('FGTeeV', 'PopularMMOs'), 68627),
#  (('Ali-A', 'Ninja'), 68585),
#  (('Poke', 'Tofuu'), 68445),
#  (('PewDiePie', 'TobyGames'), 67828),
#  (('PewDiePie', 'theRadBrad'), 67789),
#  (('CaptainSparklez', 'YOGSCAST Lewis & Sim...'), 67774),
#  (('DanTDM', 'Flamingo'), 67723),
#  (('Aphmau', 'LDShadowLady'), 67668),
#  (('PopularMMOs', 'TheAtlanticCraft'), 66885),
#  (('PopularMMOs', 'Thinknoodles'), 65977),
#  (('IGN', 'PewDiePie'), 65921),
#  (('DanTDM', 'Little Lizard Advent...'), 65361),
#  (('Ali-A', 'TheSyndicateProject'), 64905),
#  (('Denis', 'InquisitorMaster'), 64795),
#  (('Ali-A', 'TmarTn'), 64689),
#  (('PopularMMOs', 'iBallisticSquid'), 64312),
#  (('SSundee', 'stampylonghead'), 63735),
#  (('Markiplier', 'SSundee'), 63583),
#  (('Ali-A', 'TheSmithPlays'), 62677),
#  (('Ali-A', 'jacksepticeye'), 62464),
#  (('Denis', 'Poke'), 62279),
#  (('DanTDM', 'Tofuu'), 62252),
#  (('Ali-A', 'PopularMMOs'), 61881),
#  (('DanTDM', 'LDShadowLady'), 61740),
#  (('Lachlan', 'PopularMMOs'), 61623),
#  (('Grian', 'Mumbo Jumbo'), 61253),
#  (('InquisitorMaster', 'ZacharyZaxor'), 61076),
#  (('DanTDM', 'LazarBeam'), 61037),
#  (('VanossGaming', 'jacksepticeye'), 60919),
#  (('DanTDM', 'Logdotzip'), 60285),
#  (('Ali-A', 'Chaos'), 59862),
#  (('DanTDM', 'XboxAddictionz'), 59812),
#  (('PopularMMOs', 'iHasCupquake'), 59768),
#  (('Lachlan', 'Preston'), 59713),
#  (('CaptainSparklez', 'DanTDM'), 59377),
#  (('H2ODelirious', 'VanossGaming'), 58770),
#  (('Sjin', 'YOGSCAST Lewis & Sim...'), 58299),
#  (('DanTDM', 'PinkSheep'), 58268),
#  (('InquisitorMaster', 'Poke'), 57791),
#  (('Ali-A', 'BCC Trolling'), 57628),
#  (('Little Lizard Advent...', 'PopularMMOs'), 57614),
#  (('Sky Does Everything', 'stampylonghead'), 57445),
#  (('LDShadowLady', 'stacyplays'), 57104),
#  (('PewDiePie', 'YOGSCAST Lewis & Sim...'), 56972),
#  (('Aphmau', 'Sky Does Everything'), 56832),
#  (('DanTDM', 'VenturianTale'), 56814),
#  (('Denis', 'Tofuu'), 56695),
#  (('jacksepticeye', 'stampylonghead'), 56537),
#  (('Sky Does Everything', 'The Game Theorists'), 56386),
#  (('Ali-A', 'theRadBrad'), 55906),
#  (('Ali-A', 'MoreAliA'), 55841),
#  (('PewDiePie', 'Smosh Games'), 55840),
#  (('LDShadowLady', 'iHasCupquake'), 55723),
#  (('Denis', 'The Pals'), 55590),
#  (('SSundee', 'The Game Theorists'), 55161),
#  (('MooseCraft', 'UnspeakableGaming'), 55094),
#  (('DanTDM', 'Poke'), 55057),
#  (('Ali-A', 'Ceeday'), 54787),
#  (('Denis', 'Flamingo'), 54665),
#  (('Grian', 'PopularMMOs'), 54401),
#  (('Joey Graceffa', 'LDShadowLady'), 54014),
#  (('Ceeday', 'LazarBeam'), 53905),
#  (('PewDiePie', 'VanossGaming'), 53362),
#  (('Shark', 'UnspeakableGaming'), 52732),
#  (('IGN', 'theRadBrad'), 52678),
#  (('AngryJoeShow', 'IGN'), 52494),
#  (('LazarBeam', 'PewDiePie'), 52420),
#  (('Sky Does Everything', 'YOGSCAST Lewis & Sim...'), 52365),
#  (('Alex', 'Denis'), 52119),
#  (('Flamingo', 'InquisitorMaster'), 52097),
#  (('Sky Does Everything', 'TobyGames'), 51945),
#  (('LDShadowLady', 'Yammy'), 51937),
#  (('DanTDM', 'Mumbo Jumbo'), 51207),
#  (('Minecraft Universe', 'Sky Does Everything'), 50643),
#  (('Flamingo', 'Poke'), 50464),
#  (('Ali-A', 'WhiteBoy7thst'), 50145),
#  (('InquisitorMaster', 'PopularMMOs'), 50126),
#  (('Sky Does Everything', 'iHasCupquake'), 49967),
#  (('Logdotzip', 'PopularMMOs'), 49842),
#  (('Bajan Canadian', 'DanTDM'), 49838),
#  (('Aphmau', 'ItsFunneh'), 49827),
#  (('LazarBeam', 'SSundee'), 49779),
#  (('Flamingo', 'PopularMMOs'), 49593),
#  (('jacksepticeye', 'theRadBrad'), 49476),
#  (('Muselk', 'PewDiePie'), 49316),
#  (('Muselk', 'jacksepticeye'), 49300),
#  (('Denis', 'FGTeeV'), 49254),
#  (('GhostNinja', 'Lachlan'), 49227),
#  (('DanTDM', 'InquisitorMaster'), 49151),
#  (('SSundee', 'TheAtlanticCraft'), 49150),
#  (('PopularMMOs', 'XboxAddictionz'), 49075),
#  (('Ceeday', 'Lachlan'), 48995),
#  (('DanTDM', 'Muselk'), 48980),
#  (('H2ODelirious', 'jacksepticeye'), 48977),
#  (('GhostNinja', 'Home Of Games'), 48974),
#  (('Denis', 'Sketch'), 48721),
#  (('Flamingo', 'Tofuu'), 48711),
#  (('PopularMMOs', 'Tofuu'), 48697),
#  (('GameGrumps', 'Markiplier'), 48416),
#  (('AntVenom', 'CaptainSparklez'), 48345),
#  (('ItsFunneh', 'PopularMMOs'), 47965),
#  (('Bajan Canadian', 'Preston'), 47900),
#  (('Muselk', 'SSundee'), 47714),
#  (('IGN', 'The Game Theorists'), 47585),
#  (('Ali-A', 'IGN'), 47577),
#  (('Denis', 'UnspeakableGaming'), 47313),
#  (('DanTDM', 'GamingWithJen'), 47219),
#  (('Markiplier', 'VanossGaming'), 47154),
#  (('IGN', 'gameranx'), 47135),
#  (('GameSpot', 'PewDiePie'), 46701),
#  (('InquisitorMaster', 'ZaiLetsPlay'), 46683),
#  (('Ali-A', 'Hollow'), 46479),
#  (('CaptainSparklez', 'TheSyndicateProject'), 46458),
#  (('Bajan Canadian', 'CaptainSparklez'), 46423),
#  (('Lachlan', 'Ninja'), 46363),
#  (('CaptainSparklez', 'jacksepticeye'), 46103),
#  (('GhostNinja', 'ShuffleGamer'), 46093),
#  (('Duncan', 'YOGSCAST Lewis & Sim...'), 45895),
#  (('Miniminter', 'W2S'), 45895),
#  (('Aphmau', 'iHasCupquake'), 45682),
#  (('DanTDM', 'VanossGaming'), 45582),
#  (('Lachlan', 'Landon'), 45560),
#  (('XboxAddictionz', 'jacksepticeye'), 45167),
#  (('DanTDM', 'NicsterV'), 45123),
#  (('Ali-A', 'Landon'), 45072),
#  (('CaptainSparklez', 'PopularMMOs'), 45064),
#  (('IGN', 'PlayStation'), 45053),
#  (('Buzz', 'DanTDM'), 45020),
#  (('Bajan Canadian', 'PopularMMOs'), 44842),
#  (('DanTDM', 'Guava Juice'), 44771),
#  (('CaptainSparklez', 'Markiplier'), 44771),
#  (('LeafyIsHere', 'PewDiePie'), 44732),
#  (('Ceeday', 'Muselk'), 44665),
#  (('LDShadowLady', 'LaurenzSide'), 44613),
#  (('Sky Does Everything', 'TheAtlanticCraft'), 44310),
#  (('Kubz Scouts', 'Yandere Dev'), 44138),
#  (('LazarBeam', 'PopularMMOs'), 44075),
#  (('Mumbo Jumbo', 'PewDiePie'), 43896),
#  (('GameGrumps', 'The Game Theorists'), 43729),
#  (('PewDiePie', 'TheSyndicateProject'), 43588),
#  (('Crainer', 'jacksepticeye'), 43574),
#  (('LazarBeam', 'jacksepticeye'), 43542),
#  (('AntVenom', 'Sky Does Everything'), 43460),
#  (('DanTDM', 'RageElixir'), 43382),
#  (('PopularMMOs', 'VenturianTale'), 43369),
#  (('Ali-A', 'Preston'), 43322),
#  (('Lachlan', 'PewDiePie'), 43230),
#  (('CaptainSparklez', 'TobyGames'), 43220),
#  (('AngryJoeShow', 'GameSpot'), 43110),
#  (('NicsterV', 'Poke'), 42871),
#  (('TobyGames', 'YOGSCAST Lewis & Sim...'), 42796),
#  (('Poke', 'PopularMMOs'), 42701),
#  (('CaptainSparklez', 'The Game Theorists'), 42476),
#  (('Ali-A', 'W2S'), 42377),
#  (('MattHDGamer', 'W2S'), 42342),
#  (('Bigbst4tz2', 'DanTDM'), 42145),
#  (('Ant', 'Poke'), 42064),
#  (('Markiplier', 'theRadBrad'), 42030),
#  (('Ali-A', 'Sky Does Everything'), 41993),
#  (('Preston', 'jacksepticeye'), 41745),
#  (('Muselk', 'Ninja'), 41734),
#  (('Grian', 'jacksepticeye'), 41624),
#  (('DanTDM', 'Kubz Scouts'), 41514),
#  (('VenturianTale', 'jacksepticeye'), 41322),
#  (('Sky Does Everything', 'ZexyZek'), 41290),
#  (('Ali-A', 'TBNRFrags'), 41210),
#  (('Denis', 'NicsterV'), 41131),
#  (('Sips', 'YOGSCAST Lewis & Sim...'), 41083),
#  (('JeromeASF', 'Preston'), 40951),
#  (('Grian', 'PewDiePie'), 40948),
#  (('PewDiePie', 'stampylonghead'), 40851),
#  (('DanTDM', 'JeromeASF'), 40772),
#  (('GameXplain', 'Nintendo'), 40709),
#  (('Sky Does Everything', 'VenturianTale'), 40708),
#  (('GhostNinja', 'LazarBeam'), 40687),
#  (('IGN', 'Markiplier'), 40589),
#  (('LazarBeam', 'Ninja'), 40507),
#  (('Ali-A', 'VanossGaming'), 40431),
#  (('DanTDM', 'MagmaMusen'), 40353),
#  (('PinkSheep', 'PopularMMOs'), 40334),
#  (('SSundee', 'UnspeakableGaming'), 40329),
#  (('Kubz Scouts', 'jacksepticeye'), 40189),
#  (('League of Legends', 'SkinSpotlights'), 40151),
#  (('Ali-A', 'CaptainSparklez'), 40098),
#  (('NicsterV', 'Tofuu'), 39995),
#  (('Ali-A', 'LispyJimmy'), 39720),
#  (('Ali-A', 'stampylonghead'), 39706),
#  (('PopularMMOs', 'VanossGaming'), 39634),
#  (('MooseCraft', 'PopularMMOs'), 39150),
#  (('Alex', 'DanTDM'), 39139),
#  (('Lachlan', 'jacksepticeye'), 39099),
#  (('Muselk', 'PopularMMOs'), 39085),
#  (('Poke', 'ZephPlayz'), 39041),
#  (('JeromeASF', 'PopularMMOs'), 38870),
#  (('LevelCapGaming', 'jackfrags'), 38870),
#  (('Please Stand By', 'Sky Does Everything'), 38845),
#  (('LaurenzSide', 'PopularMMOs'), 38810),
#  (('Sky Does Everything', 'VanossGaming'), 38717),
#  (('DanTDM', 'FusionZGamer'), 38677),
#  (('Sky Does Everything', 'Smosh Games'), 38626),
#  (('Markiplier', 'iHasCupquake'), 38595),
#  (('SSundee', 'VanossGaming'), 38581),
#  (('Kubz Scouts', 'PopularMMOs'), 38523),
#  (('GameSpot', 'theRadBrad'), 38518),
#  (('TheSyndicateProject', 'WhiteBoy7thst'), 38435),
#  (('Denis', 'ZephPlayz'), 38274),
#  (('Sky Does Everything', 'TheSyndicateProject'), 38240),
#  (('MattHDGamer', 'TWOSYNC'), 38238),
#  (('Joey Graceffa', 'stacyplays'), 38222),
#  (('Preston', 'stampylonghead'), 38178),
#  (('Little Carly Minecra...', 'Little Kelly Minecra...'), 38170),
#  (('Ali-A', 'M3RKMUS1C'), 38115),
#  (('Little Kelly Minecra...', 'PopularMMOs'), 38030),
#  (('IGN', 'Nintendo'), 37951),
#  (('LazarBeam', 'MrTop5'), 37945),
#  (('CaptainSparklez', 'JeromeASF'), 37938),
#  (('AA9skillz', 'MattHDGamer'), 37938),
#  (('DanTDM', 'The Pals'), 37910),
#  (('CaptainSparklez', 'Please Stand By'), 37819),
#  (('Preston', 'Sky Does Everything'), 37690),
#  (('DanTDM', 'ItsFunneh'), 37687),
#  (('SSundee', 'Thinknoodles'), 37671),
#  (('Flamingo', 'NicsterV'), 37509),
#  (('Nintendo', 'The Game Theorists'), 37499),
#  (('Markiplier', 'VenturianTale'), 37482),
#  (('Lachlan', 'TheSmithPlays'), 37415),
#  (('Ninja', 'Tfue'), 37345),
#  (('PewDiePie', 'iHasCupquake'), 37268),
#  (('BCC Trolling', 'PewDiePie'), 37184),
#  (('GameGrumps', 'PewDiePie'), 37148),
#  (('SSundee', 'Thea & Crainer - Min...'), 37136),
#  (('H2ODelirious', 'PewDiePie'), 37054),
#  (('Ali-A', 'Markiplier'), 37044),
#  (('AA9skillz', 'NepentheZ'), 37030),
#  (('Grian', 'The Game Theorists'), 36906),
#  (('Aphmau', 'SmallishBeans'), 36889),
#  (('Crainer', 'Preston'), 36856),
#  (('AntVenom', 'PewDiePie'), 36843),
#  (('Denis', 'ItsFunneh'), 36826),
#  (('Kubz Scouts', 'Markiplier'), 36758),
#  (('GameGrumps', 'jacksepticeye'), 36752),
#  (('PopularMMOs', 'stacyplays'), 36722),
#  (('PopularMMOs', 'SmallishBeans'), 36699),
#  (('Hyper - Roblox', 'Poke'), 36630),
#  (('LeafyIsHere', 'jacksepticeye'), 36592),
#  (('Grian', 'UnspeakableGaming'), 36584),
#  (('GhostNinja', 'Muselk'), 36578),
#  (('Bajan Canadian', 'PewDiePie'), 36496),
#  (('iHasCupquake', 'jacksepticeye'), 36394),
#  (('DanTDM', 'ibxtoycat'), 36385),
#  (('Joey Graceffa', 'SmallishBeans'), 36361),
#  (('Landon', 'LazarBeam'), 36337),
#  (('Aphmau', 'LaurenzSide'), 36333),
#  (('Markiplier', 'stampylonghead'), 36328),
#  (('Mumbo Jumbo', 'PopularMMOs'), 36313),
#  (('BCC Trolling', 'Lachlan'), 36268),
#  (('MattHDGamer', 'NepentheZ'), 36189),
#  (('DanTDM', 'LaurenzSide'), 36177),
#  (('UnspeakableGaming', 'jacksepticeye'), 36176),
#  (('MOLT', 'nickatnyte'), 36135),
#  (('Logdotzip', 'UnspeakableGaming'), 36105),
#  (('Muselk', 'TheSmithPlays'), 36074),
#  (('PewDiePie', 'XboxAddictionz'), 36015),
#  (('Mumbo Jumbo', 'jacksepticeye'), 35951),
#  (('PopularMMOs', 'RageElixir'), 35834),
#  (('TheAtlanticCraft', 'jacksepticeye'), 35761),
#  (('Ceeday', 'Ninja'), 35736),
#  (('PopularMMOs', 'UnspeakablePlays'), 35732),
#  (('IGN', 'jacksepticeye'), 35707),
#  (('Ali-A', 'BigFoltz'), 35699),
#  (('DanTDM', 'Jelly'), 35670),
#  (('DanTDM', 'ZephPlayz'), 35655),
#  (('InquisitorMaster', 'realrosesarered'), 35638),
#  (('BCC Trolling', 'Ninja'), 35607),
#  (('DanTDM', 'EthanGamer'), 35505),
#  (('InquisitorMaster', 'Tofuu'), 35469),
#  (('GameSpot', 'gameranx'), 35415),
#  (('Mumbo Jumbo', 'The Game Theorists'), 35404),
#  (('Ant', 'Tofuu'), 35375),
#  (('Ali-A', 'Fortnite Funny'), 35292),
#  (('SmallishBeans', 'stacyplays'), 35244),
#  (('DanTDM', 'ThnxCya'), 35216),
#  (('iHasCupquake', 'stampylonghead'), 35184),
#  (('InquisitorMaster', 'MeganPlays Roblox'), 35178),
#  (('Aphmau', 'stacyplays'), 35150),
#  (('PewDiePie', 'UberHaxorNova'), 35059),
#  (('DanTDM', 'ZexyZek'), 35012),
#  (('BCC Trolling', 'Muselk'), 34885),
#  (('SmallishBeans', 'Yammy'), 34880),
#  (('Guava Juice', 'PopularMMOs'), 34876),
#  (('H2ODelirious', 'Markiplier'), 34868),
#  (('BCC Trolling', 'LazarBeam'), 34816),
#  (('M3RKMUS1C', 'PewDiePie'), 34793),
#  (('LazarBeam', 'Top5Gaming'), 34729),
#  (('SSundee', 'iBallisticSquid'), 34634),
#  (('Denis', 'Preston'), 34609),
#  (('DanTDM', 'UnspeakablePlays'), 34514),
#  (('Duncan', 'Sjin'), 34387),
#  (('Little Carly Minecra...', 'PopularMMOs'), 34364),
#  (('Grian', 'SSundee'), 34362),
#  (('UberHaxorNova', 'YOGSCAST Lewis & Sim...'), 34340),
#  (('Muselk', 'The Game Theorists'), 34336),
#  (('Bijuu Mike', 'DanTDM'), 34254),
#  (('DanTDM', 'Doni Bobes'), 34232),
#  (('PewDiePie', 'Preston'), 34194),
#  (('NicsterV', 'ZephPlayz'), 34096),
#  (('Aphmau', 'jacksepticeye'), 34079),
#  (('TheSyndicateProject', 'YOGSCAST Lewis & Sim...'), 34069),
#  (('GhostNinja', 'Landon'), 34035),
#  (('PewDiePie', 'videogames'), 34034),
#  (('Thinknoodles', 'stampylonghead'), 34026),
#  (('Sky Does Everything', 'theRadBrad'), 33974),
#  (('I AM WILDCAT', 'VanossGaming'), 33957),
#  (('DanTDM', 'MrTop5'), 33919),
#  (('Flamingo', 'PewDiePie'), 33907),
#  (('DanTDM', 'MooseCraft'), 33873),
#  (('Tofuu', 'ZephPlayz'), 33856),
#  (('DanTDM', 'Landon'), 33833),
#  (('Preston', 'TBNRFrags'), 33771),
#  (('CoryxKenshin', 'DanTDM'), 33709),
#  (('Denis', 'Thinknoodles'), 33700),
#  (('Little Lizard Advent...', 'stampylonghead'), 33682),
#  (('Ali-A', 'FaZe Clan'), 33661),
#  (('Bajan Canadian', 'Lachlan'), 33653),
#  (('Ali-A', 'NoahJ456'), 33642),
#  (('Home Of Games', 'ShuffleGamer'), 33641),
#  (('Ceeday', 'PewDiePie'), 33585),
#  (('Ali-A', 'The Game Theorists'), 33584),
#  (('Shark', 'UnspeakablePlays'), 33583),
#  (('SSundee', 'XboxAddictionz'), 33580),
#  (('Ali-A', 'ShuffleGamer'), 33494),
#  (('Grian', 'Logdotzip'), 33442),
#  (('MrWoofless', 'Preston'), 33430),
#  (('Crainer', 'Lachlan'), 33416),
#  (('LeafyIsHere', 'Markiplier'), 33385),
#  (('Jelly', 'Kwebbelkop'), 33196),
#  (('BCC Trolling', 'DanTDM'), 33174),
#  (('PewDiePie', 'gameranx'), 33142),
#  (('Buzz', 'PopularMMOs'), 33115),
#  (('GTLive', 'The Game Theorists'), 33110),
#  (('Lachlan', 'TBNRFrags'), 33066),
#  (('Denis', 'jacksepticeye'), 33034),
#  (('Markiplier', 'XboxAddictionz'), 33014),
#  (('TheAtlanticCraft', 'stampylonghead'), 32995),
#  (('Ali-A', 'Cizzorz'), 32953),
#  (('AntVenom', 'DanTDM'), 32953),
#  (('iHasCupquake', 'stacyplays'), 32943),
#  (('Ali-A', 'Tfue'), 32941),
#  (('DanTDM', 'Little Kelly Minecra...'), 32903),
#  (('GameSpot', 'PlayStation'), 32837),
#  (('Aphmau', 'InquisitorMaster'), 32830),
#  (('PopularMMOs', 'Shark'), 32792),
#  (('MattHDGamer', 'Miniminter'), 32769),
#  (('DanTDM', 'LispyJimmy'), 32717),
#  (('Preston', 'UnspeakablePlays'), 32710),
#  (('Fe4RLess', 'LazarBeam'), 32705),
#  (('InquisitorMaster', 'NicsterV'), 32705),
#  (('LazarBeam', 'TheSmithPlays'), 32601),
#  (('DanTDM', 'iDeactivateMC'), 32579),
#  (('DanTDM', 'SmallishBeans'), 32563),
#  (('GameSpot', 'The Game Theorists'), 32486),
#  (('DanTDM', 'MangoTango'), 32408),
#  (('Ali-A', 'TmarTn2'), 32390),
#  (('UnspeakableGaming', 'stampylonghead'), 32384),
#  (('GhostNinja', 'Ninja'), 32303),
#  (('TWOSYNC', 'W2S'), 32276),
#  (('ItsFunneh', 'LDShadowLady'), 32216),
#  (('InquisitorMaster', 'ZephPlayz'), 32183),
#  (('Ali-A', 'GameSpot'), 32156),
#  (('DanTDM', 'Samgladiator'), 32143),
#  (('DanTDM', 'Kazok'), 32099),
#  (('Sips', 'Sjin'), 32096),
#  (('Little Lizard Advent...', 'TheAtlanticCraft'), 32094),
#  (('BCC Trolling', 'Ceeday'), 32043),
#  (('Ceeday', 'DanTDM'), 32025),
#  (('GhostNinja', 'iTankid'), 32015),
#  (('Flamingo', 'jacksepticeye'), 31975),
#  (('Landon', 'Muselk'), 31965),
#  (('TmarTn', 'WhiteBoy7thst'), 31944),
#  (('Little Lizard Advent...', 'SSundee'), 31902),
#  (('The Game Theorists', 'stampylonghead'), 31854),
#  (('Bigbst4tz2', 'PopularMMOs'), 31832),
#  (('DanTDM', 'stacyplays'), 31825),
#  (('League of Legends', 'PewDiePie'), 31824),
#  (('Mumbo Jumbo', 'SSundee'), 31822),
#  (('SSundee', 'ZexyZek'), 31818),
#  (('LazarBeam', 'Twine Cheeks'), 31784),
#  (('IGN', 'MKIceAndFire'), 31776),
#  (('Logdotzip', 'Mumbo Jumbo'), 31665),
#  (('Gamer Chad', 'PopularMMOs'), 31622),
#  (('Ali-A', 'Twine Cheeks'), 31605),
#  (('DanTDM', 'Little Carly Minecra...'), 31575),
#  (('Sqaishey Quack', 'stampylonghead'), 31557),
#  (('Ninja', 'PewDiePie'), 31539),
#  (('MattHDGamer', 'bateson87'), 31533),
#  (('DanTDM', 'Ninja'), 31494),
#  (('Aphmau', 'Markiplier'), 31489),
#  (('Ali-A', 'MrDalekJD'), 31473),
#  (('DanTDM', 'ZackScottGames'), 31457),
#  (('Doni Bobes', 'PopularMMOs'), 31445),
#  (('Please Stand By', 'YOGSCAST Lewis & Sim...'), 31439),
#  (('Crainer', 'Sky Does Everything'), 31434),
#  (('Bijuu Mike', 'Kubz Scouts'), 31394),
#  (('DanTDM', 'Minecraft Universe'), 31361),
#  (('DanTDM', 'GhostNinja'), 31184),
#  (('LDShadowLady', 'stampylonghead'), 31180),
#  (('Ali-A', 'Home Of Games'), 31163),
#  (('GhostNinja', 'SSundee'), 30988),
#  (('Ali-A', 'jackfrags'), 30959),
#  (('Ceeday', 'NoahsNoah'), 30950),
#  (('Aphmau', 'stampylonghead'), 30943),
#  (('NicsterV', 'PopularMMOs'), 30860),
#  (('IGN', 'jackfrags'), 30858),
#  (('DanTDM', 'Sketch'), 30844),
#  (('DanTDM', 'theRadBrad'), 30825),
#  (('Markiplier', 'Yandere Dev'), 30805),
#  (('DanTDM', 'TheSmithPlays'), 30778),
#  (('PopularMMOs', 'Yammy'), 30776),
#  (('CoryxKenshin', 'jacksepticeye'), 30693),
#  (('Joey Graceffa', 'PopularMMOs'), 30666),
#  (('Ant', 'Denis'), 30645),
#  (('DanTDM', 'Gamer Chad'), 30638),
#  (('Grian', 'Preston'), 30600),
#  (('The Game Theorists', 'gameranx'), 30570),
#  (('PewDiePie', 'SeaNanners Gaming Ch...'), 30531),
#  (('The Game Theorists', 'VanossGaming'), 30521),
#  (('LaurenzSide', 'Yammy'), 30475),
#  (('JeromeASF', 'Lachlan'), 30352),
#  (('M3RKMUS1C', 'jacksepticeye'), 30306),
#  (('Landon', 'Preston'), 30300),
#  (('InTheLittleWood', 'YOGSCAST Lewis & Sim...'), 30260),
#  (('Logdotzip', 'SSundee'), 30222),
#  (('Aphmau', 'SSundee'), 30181),
#  (('GameXplain', 'IGN'), 30172),
#  (('InquisitorMaster', 'VuxVux'), 30166),
#  (('BCC Trolling', 'jacksepticeye'), 30132),
#  (('Markiplier', 'Muselk'), 30129),
#  (('Minecraft', 'PewDiePie'), 30094),
#  (('LeafyIsHere', 'The Game Theorists'), 30011),
#  (('Flamingo', 'ZephPlayz'), 29966),
#  (('Denis', 'Kazok'), 29965),
#  (('DanTDM', 'Shark'), 29956),
#  (('H2ODelirious', 'I AM WILDCAT'), 29947),
#  (('Denis', 'Gamer Chad'), 29945),
#  (('GONTH', 'MattHDGamer'), 29930),
#  (('Gamer Chad', 'RadioJH Games'), 29917),
#  (('JMX', 'W2S'), 29899),
#  (('AntVenom', 'YOGSCAST Lewis & Sim...'), 29852),
#  (('Ali-A', 'Sernandoe'), 29848),
#  (('AngryJoeShow', 'PewDiePie'), 29817),
#  (('Poke', 'SeeDeng'), 29810),
#  (('JeromeASF', 'PewDiePie'), 29810),
#  (('FusionZGamer', 'PopularMMOs'), 29801),
#  (('GameXplain', 'The Game Theorists'), 29785),
#  (('InquisitorMaster', 'LaurenzSide'), 29780),
#  (('Minecraft Universe', 'SSundee'), 29768),
#  (('PewDiePie', 'VenturianTale'), 29756),
#  (('DanTDM', 'Sernandoe'), 29739),
#  (('AA9skillz', 'TWOSYNC'), 29680),
#  (('Ceeday', 'Fortnite Funny'), 29666),
#  (('SSundee', 'VenturianTale'), 29640),
#  (('ItsFunneh', 'Poke'), 29620),
#  (('Sky Does Everything', 'videogames'), 29615),
#  (('Ali-A', 'H2ODelirious'), 29598),
#  (('CaptainSparklez', 'Crainer'), 29583),
#  (('WhiteBoy7thst', 'WoodysGamertag'), 29541),
#  (('CaptainSparklez', 'SethBling'), 29513),
#  (('Logdotzip', 'Preston'), 29467),
#  (('SSundee', 'TheCampingRusher - F...'), 29464),
#  (('Logdotzip', 'jacksepticeye'), 29462),
#  (('Markiplier', 'TobyGames'), 29434),
#  (('CaptainSparklez', 'Minecraft Universe'), 29414),
#  (('Grian', 'stampylonghead'), 29401),
#  (('Logdotzip', 'PewDiePie'), 29374),
#  (('SmallishBeans', 'iHasCupquake'), 29328),
#  (('The Game Theorists', 'theRadBrad'), 29324),
#  (('TheSyndicateProject', 'TmarTn'), 29295),
#  (('League of Legends', 'Redmercy'), 29256),
#  (('MooseCraft', 'Shark'), 29252),
#  (('Thinknoodles', 'jacksepticeye'), 29221),
#  (('Ali-A', 'Crainer'), 29220),
#  (('DanTDM', 'H2ODelirious'), 29178),
#  (('SSundee', 'theRadBrad'), 29164),
#  (('Denis', 'SSundee'), 29150),
#  (('Lachlan', 'Top5Gaming'), 29136),
#  (('General Tony', 'PopularMMOs'), 29125),
#  (('Landon', 'SSundee'), 29109),
#  (('MangoTango', 'PopularMMOs'), 29089),
#  (('SSundee', 'Tofuu'), 29064),
#  (('AA9skillz', 'W2S'), 28999),
#  (('iBallisticSquid', 'jacksepticeye'), 28984),
#  (('BigFoltz', 'GhostNinja'), 28965),
#  (('FusionZGamer', 'Markiplier'), 28956),
#  (('InquisitorMaster', 'Keisyo'), 28955),
#  (('Landon', 'PopularMMOs'), 28922),
#  (('RageElixir', 'UnspeakableGaming'), 28912),
#  (('Flamingo', 'Jayingee'), 28852),
#  (('Preston', 'Vikkstar123HD'), 28798),
#  (('Aphmau', 'Kubz Scouts'), 28773),
#  (('Denis', 'stampylonghead'), 28734),
#  (('FGTeeV', 'stampylonghead'), 28725),
#  (('LDShadowLady', 'SeaPeeKay'), 28718),
#  (('GONTH', 'W2S'), 28703),
#  (('Lachlan', 'Twine Cheeks'), 28656),
#  (('Flamingo', 'greenlegocats123'), 28634),
#  (('The Game Theorists', 'YOGSCAST Lewis & Sim...'), 28627),
#  (('PewDiePie', 'jackfrags'), 28585),
#  (('Ceeday', 'GhostNinja'), 28571),
#  (('DanTDM', 'General Tony'), 28546),
#  (('NepentheZ', 'bateson87'), 28524),
#  (('Lachlan', 'MrTop5'), 28486),
#  (('Joey Graceffa', 'iHasCupquake'), 28460),
#  (('Aphmau', 'Yammy'), 28449),
#  (('Ceeday', 'Fe4RLess'), 28431),
#  (('Ali-A', 'Bajan Canadian'), 28394),
#  (('Aphmau', 'Joey Graceffa'), 28374),
#  (('GameSpot', 'Markiplier'), 28330),
#  (('Crainer', 'Thea & Crainer - Min...'), 28330),
#  (('CaptainSparklez', 'UberHaxorNova'), 28299),
#  (('Ali-A', 'Drift0r'), 28293),
#  (('Ali-A', 'TheCampingRusher - F...'), 28270),
#  (('Grian', 'Markiplier'), 28263),
#  (('Markiplier', 'Smosh Games'), 28210),
#  (('CoryxKenshin', 'PopularMMOs'), 28176),
#  (('Denis', 'Sub'), 28173),
#  (('Daithi De Nogla', 'VanossGaming'), 28118),
#  (('Ali-A', 'Top5Gaming'), 28113),
#  (('BCC Trolling', 'SSundee'), 28104),
#  (('FGTeeV', 'UnspeakableGaming'), 28092),
#  (('FGTeeV', 'InquisitorMaster'), 28087),
#  (('8-BitRyan', 'DanTDM'), 28073),
#  (('Jelly', 'PopularMMOs'), 28053),
#  (('Bijuu Mike', 'PopularMMOs'), 28039),
#  (('DanTDM', 'Kwebbelkop'), 27996),
#  (('Flamingo', 'ItsFunneh'), 27994),
#  (('Ali-A', 'MrTop5'), 27980),
#  (('PewDiePie', 'UnspeakableGaming'), 27969),
#  (('Mumbo Jumbo', 'UnspeakableGaming'), 27964),
#  (('PewDiePie', 'TheSmithPlays'), 27917),
#  (('Yandere Dev', 'jacksepticeye'), 27905),
#  (('GhostNinja', 'LispyJimmy'), 27893),
#  (('Sky Does Everything', 'iBallisticSquid'), 27864),
#  (('Jelly', 'jacksepticeye'), 27845),
#  (('MrBossFTW', 'Saintsfan'), 27841),
#  (('Denis', 'Guava Juice'), 27821),
#  (('Poke', 'ZacharyZaxor'), 27811),
#  (('Fandom Games', 'The Game Theorists'), 27802),
#  (('DanTDM', 'MessYourself'), 27774),
#  (('CaptainSparklez', 'Preston'), 27770),
#  (('Lachlan', 'Tfue'), 27738),
#  (('Fandom Games', 'PewDiePie'), 27735),
#  (('MooseCraft', 'UnspeakablePlays'), 27692),
#  (('CaptainSparklez', 'SeaNanners Gaming Ch...'), 27671),
#  (('SSundee', 'iHasCupquake'), 27573),
#  (('Bajan Canadian', 'MrWoofless'), 27547),
#  (('SeeDeng', 'Tofuu'), 27546),
#  (('Ceeday', 'TheSmithPlays'), 27545),
#  (('Markiplier', 'YOGSCAST Lewis & Sim...'), 27479),
#  (('Tofuu', 'UnspeakableGaming'), 27458),
#  (('PopularMMOs', 'The Pals'), 27424),
#  (('LazarBeam', 'Tfue'), 27368),
#  (('Chaos', 'PewDiePie'), 27358),
#  (('Ali-A', 'Jelly'), 27343),
#  (('Fe4RLess', 'Lachlan'), 27333),
#  (('IGN', 'YongYea'), 27325),
#  (('Ali-A', 'Vikkstar123'), 27325),
#  (('Mumbo Jumbo', 'xisumavoid'), 27318),
#  (('MooseCraft', 'Preston'), 27311),
#  (('Home Of Games', 'LazarBeam'), 27297),
#  (('DanTDM', 'Top5Gaming'), 27283),
#  (('Sky Does Everything', 'XboxAddictionz'), 27278),
#  (('LaurenzSide', 'SmallishBeans'), 27267),
#  (('Logdotzip', 'The Game Theorists'), 27266),
#  (('AngryJoeShow', 'gameranx'), 27222),
#  (('LispyJimmy', 'Sernandoe'), 27222),
#  (('DanTDM', 'Minecraft'), 27217),
#  (('PewDiePie', 'ibxtoycat'), 27209),
#  (('Flamingo', 'VuxVux'), 27182),
#  (('PopularMMOs', 'ibxtoycat'), 27160),
#  (('Lachlan', 'UnspeakableGaming'), 27145),
#  (('Preston', 'Shark'), 27137),
#  (('MagmaMusen', 'PopularMMOs'), 27137),
#  (('AA9skillz', 'bateson87'), 27121),
#  (('UberHaxorNova', 'xXSlyFoxHoundXx'), 27110),
#  (('The Game Theorists', 'Yandere Dev'), 27106),
#  (('Fortnite Funny', 'Lachlan'), 27084),
#  (('General Tony', 'SSundee'), 27054),
#  (('LaurenzSide', 'iHasCupquake'), 27052),
#  (('gameranx', 'jacksepticeye'), 27017),
#  (('Bajan Canadian', 'jacksepticeye'), 27012),
#  (('XboxAddictionz', 'stampylonghead'), 26999),
#  (('Poke', 'UnspeakableGaming'), 26998),
#  (('EthosLab', 'VintageBeef'), 26982),
#  (('Bajan Canadian', 'stampylonghead'), 26974),
#  (('Ali-A', 'speedyw03'), 26970),
#  (('AntVenom', 'The Game Theorists'), 26964),
#  (('FGTeeV', 'SSundee'), 26958),
#  (('VanossGaming', 'theRadBrad'), 26923),
#  (('Fortnite Funny', 'Ninja'), 26922),
#  (('LispyJimmy', 'jacksepticeye'), 26921),
#  (('CaptainSparklez', 'EthosLab'), 26913),
#  (('Ceeday', 'Landon'), 26901),
#  (('LazarBeam', 'ShuffleGamer'), 26884),
#  (('Jelly', 'SSundee'), 26879),
#  (('Ali-A', 'NoahsNoah'), 26853),
#  (('AA9skillz', 'Miniminter'), 26849),
#  (('Ali-A', 'Kiwiz'), 26825),
#  (('Ali-A', 'FaZe Apex'), 26794),
#  (('Ali-A', 'Fe4RLess'), 26783),
#  (('ItsFunneh', 'ZaiLetsPlay'), 26777),
#  (('PopularMMOs', 'Samgladiator'), 26775),
#  (('Smosh Games', 'jacksepticeye'), 26760),
#  (('LispyJimmy', 'PopularMMOs'), 26756),
#  (('MrWoofless', 'SSundee'), 26733),
#  (('Flamingo', 'LazarBeam'), 26715),
#  (('Miniminter', 'TWOSYNC'), 26708),
#  (('TheSmithPlays', 'jacksepticeye'), 26697),
#  (('DanTDM', 'Yammy'), 26670),
#  (('SeaNanners Gaming Ch...', 'YOGSCAST Lewis & Sim...'), 26642),
#  (('CaptainSparklez', 'Mumbo Jumbo'), 26640),
#  (('Lachlan', 'stampylonghead'), 26615),
#  (('AshDubh', 'iBallisticSquid'), 26593),
#  (('GhostNinja', 'MrTop5'), 26580),
#  (('Lachlan', 'Sky Does Everything'), 26577),
#  (('SSundee', 'TheSmithPlays'), 26524),
#  (('Chaos', 'TheSmithPlays'), 26493),
#  (('Ali-A', 'Daequan Loco'), 26474),
#  (('Joey Graceffa', 'Yammy'), 26454),
#  (('LazarBeam', 'NoahsNoah'), 26395),
#  (('Kubz Scouts', 'PewDiePie'), 26391),
#  (('Ali-A', 'MrBossFTW'), 26369),
#  (('DanTDM', 'Joey Graceffa'), 26367),
#  (('CaptainSparklez', 'Sjin'), 26358),
#  (('Ali-A', 'General Tony'), 26338),
#  (('CaptainSparklez', 'theRadBrad'), 26335),
#  (('Alex', 'PopularMMOs'), 26284),
#  (('MrTop5', 'SSundee'), 26279),
#  (('ItsFunneh', 'LaurenzSide'), 26216),
#  (('LazarBeam', 'The Game Theorists'), 26203),
#  (('MessYourself', 'jacksepticeye'), 26196),
#  (('Ali-A', 'videogames'), 26192),
#  (('Bijuu Mike', 'LaurenzSide'), 26181),
#  (('Kubz Scouts', 'The Game Theorists'), 26149),
#  (('Nintendo', 'PewDiePie'), 26115),
#  (('Lachlan', 'ShuffleGamer'), 26083),
#  (('Smosh Games', 'TobyGames'), 26083),
#  (('Cizzorz', 'Lachlan'), 26079),
#  (('gameranx', 'theRadBrad'), 26077),
#  (('PewDiePie', 'ZexyZek'), 26066),
#  (('CaptainSparklez', 'stampylonghead'), 26056),
#  (('AntVenom', 'SSundee'), 26012),
#  (('Mumbo Jumbo', 'ibxtoycat'), 26006),
#  (('H2ODelirious', 'SSundee'), 26005),
#  (('H2ODelirious', 'PopularMMOs'), 26004),
#  (('Lachlan', 'TheCampingRusher - F...'), 25982),
#  (('Markiplier', 'Preston'), 25923),
#  (('Bigbst4tz2', 'stampylonghead'), 25895),
#  (('Ali-A', 'MattHDGamer'), 25881),
#  (('M3RKMUS1C', 'VanossGaming'), 25857),
#  (('Buzz', 'Denis'), 25852),
#  (('PewDiePie', 'W2S'), 25834),
#  (('BCC Trolling', 'PopularMMOs'), 25832),
#  (('Ceeday', 'SSundee'), 25831),
#  (('Smosh Games', 'The Game Theorists'), 25764),
#  (('Alpharad', 'The Game Theorists'), 25753),
#  (('Ali-A', 'UnspeakableGaming'), 25748),
#  (('Daequan Loco', 'Ninja'), 25736),
#  (('CaptainSparklez', 'iHasCupquake'), 25725),
#  (('Preston', 'Tofuu'), 25721),
#  (('The Game Theorists', 'VenturianTale'), 25719),
#  (('Aphmau', 'Preston'), 25710),
#  (('LDShadowLady', 'Sky Does Everything'), 25693),
#  (('Grian', 'ibxtoycat'), 25673),
#  (('8-BitRyan', 'jacksepticeye'), 25655),
#  (('PopularMMOs', 'TheSmithPlays'), 25649),
#  (('PopularMMOs', 'iDeactivateMC'), 25643),
#  (('Bodil40', 'Sky Does Everything'), 25606),
#  (('Ant', 'DanTDM'), 25600),
#  (('Preston', 'TheAtlanticCraft'), 25569),
#  (('Lachlan', 'Vikkstar123HD'), 25557),
#  (('Doni Bobes', 'SSundee'), 25552),
#  (('Yammy', 'iHasCupquake'), 25526),
#  (('Little Lizard Advent...', 'Sky Does Everything'), 25523),
#  (('Ceeday', 'jacksepticeye'), 25520),
#  (('Cryaotic', 'PewDiePie'), 25499),
#  (('InquisitorMaster', 'UnspeakableGaming'), 25495),
#  (('Aphmau', 'Denis'), 25470),
#  (('TmarTn', 'TmarTn2'), 25469),
#  (('SethBling', 'Sky Does Everything'), 25465),
#  (('Ali-A', 'dakotaz'), 25454),
#  (('IGN', 'lzuniy'), 25439),
#  (('Ceeday', 'Tfue'), 25415),
#  (('LazarBeam', 'UnspeakableGaming'), 25398),
#  (('GameSpot', 'jackfrags'), 25371),
#  (('FGTeeV', 'Thinknoodles'), 25354),
#  (('TheSyndicateProject', 'theRadBrad'), 25352),
#  (('InquisitorMaster', 'LDShadowLady'), 25344),
#  (('Flamingo', 'UnspeakableGaming'), 25329),
#  (('DanTDM', 'Yandere Dev'), 25318),
#  (('Bajan Canadian', 'Minecraft Universe'), 25297),
#  (('PewDiePie', 'videogamedunkey'), 25292),
#  (('Crainer', 'Markiplier'), 25285),
#  (('LazarBeam', 'Preston'), 25281),
#  (('Thinknoodles', 'Tofuu'), 25272),
#  (('Fandom Games', 'IGN'), 25250),
#  (('Flamingo', 'The Game Theorists'), 25237),
#  (('PopularMMOs', 'ZephPlayz'), 25227),
#  (('SSundee', 'TBNRFrags'), 25193),
#  (('Crainer', 'PewDiePie'), 25183),
#  (('The Game Theorists', 'XboxAddictionz'), 25175),
#  (('JMX', 'Miniminter'), 25154),
#  (('FusionZGamer', 'jacksepticeye'), 25143),
#  (('GameSpot', 'MKIceAndFire'), 25143),
#  (('FGTeeV', 'jacksepticeye'), 25105),
#  (('Markiplier', 'gameranx'), 25088),
#  (('Alex', 'The Pals'), 25080),
#  (('Ali-A', 'TheLlamaSir'), 25066),
#  (('AngryJoeShow', 'The Game Theorists'), 25049),
#  (('MrTop5', 'PopularMMOs'), 25029),
#  (('Poke', 'Preston'), 25015),
#  (('Lachlan', 'Randumb'), 24999),
#  (('Denis', 'PinkSheep'), 24996),
#  (('Kwebbelkop', 'jacksepticeye'), 24979),
#  (('PewDiePie', 'WhiteBoy7thst'), 24970),
#  (('YOGSCAST Lewis & Sim...', 'YogsLomadia'), 24953),
#  (('Ali-A', 'YOGSCAST Lewis & Sim...'), 24947),
#  (('Chaos', 'TmarTn'), 24942),
#  (('DanTDM', 'W2S'), 24930),
#  (('M3RKMUS1C', 'Markiplier'), 24929),
#  (('Ali-A', 'Randumb'), 24885),
#  (('CoryxKenshin', 'Markiplier'), 24874),
#  (('Daithi De Nogla', 'H2ODelirious'), 24861),
#  (('PopularMMOs', 'ZackScottGames'), 24849),
#  (('GhostNinja', 'Twine Cheeks'), 24782),
#  (('I AM WILDCAT', 'jacksepticeye'), 24777),
#  (('Kazok', 'Tofuu'), 24754),
#  (('NepentheZ', 'W2S'), 24708),
#  (('Markiplier', 'TheAtlanticCraft'), 24707),
#  (('Muselk', 'Preston'), 24701),
#  (('CaptainSparklez', 'ZexyZek'), 24678),
#  (('Bijuu Mike', 'jacksepticeye'), 24676),
#  (('Fortnite Funny', 'LazarBeam'), 24670),
#  (('AngryJoeShow', 'theRadBrad'), 24668),
#  (('NepentheZ', 'TWOSYNC'), 24589),
#  (('Nightblue3', 'Redmercy'), 24586),
#  (('Kubz Scouts', 'LaurenzSide'), 24561),
#  (('DanTDM', 'TheCampingRusher - F...'), 24557),
#  (('Landon - lol', 'Poke'), 24545),
#  (('Markiplier', 'Mumbo Jumbo'), 24539),
#  (('PopularMMOs', 'Thea & Crainer - Min...'), 24490),
#  (('Bijuu Mike', 'Yandere Dev'), 24484),
#  (('Ceeday', 'Twine Cheeks'), 24482),
#  (('PewDiePie', 'TheAtlanticCraft'), 24481),
#  (('AshDubh', 'DanTDM'), 24427),
#  (('H2ODelirious', 'theRadBrad'), 24406),
#  (('AntVenom', 'Mumbo Jumbo'), 24389),
#  (('JeromeASF', 'jacksepticeye'), 24387),
#  (('SeaPeeKay', 'SmallishBeans'), 24374),
#  (('Home Of Games', 'Lachlan'), 24365),
#  (('Denis', 'PewDiePie'), 24358),
#  (('Preston', 'PrestonMobile'), 24347),
#  (('jackfrags', 'theRadBrad'), 24342),
#  (('FGTeeV', 'Poke'), 24339),
#  (('GameSpot', 'jacksepticeye'), 24322),
#  (('GhostNinja', 'PopularMMOs'), 24293),
#  (('VenturianTale', 'stampylonghead'), 24286),
#  (('Crainer', 'stampylonghead'), 24275),
#  (('SSundee', 'Vikkstar123HD'), 24268),
#  (('Muselk', 'Tfue'), 24255),
#  (('DashieGames', 'jacksepticeye'), 24253),
#  (('DashieGames', 'PewDiePie'), 24248),
#  (('BCC Trolling', 'TheSmithPlays'), 24247),
#  (('MrTLexify', 'TheSmithPlays'), 24242),
#  (('M3RKMUS1C', 'Sky Does Everything'), 24236),
#  (('Kubz Scouts', 'iHasCupquake'), 24204),
#  (('Landon - lol', 'Tofuu'), 24201),
#  (('Mumbo Jumbo', 'Preston'), 24200),
#  (('Flamingo', 'Markiplier'), 24159),
#  (('Little Carly Minecra...', 'Little Donny - Minec...'), 24152),
#  (('Ali-A', 'Formula'), 24137),
#  (('CaptainSparklez', 'WhiteBoy7thst'), 24133),
#  (('AshleyTheUnicorn', 'InquisitorMaster'), 24122),
#  (('Bajan Canadian', 'Vikkstar123HD'), 24116),
#  (('Ali-A', 'FaZe Blaze'), 24099),
#  (('Preston', 'The Game Theorists'), 24095),
#  (('Hyper - Roblox', 'InquisitorMaster'), 24092),
#  (('Ali-A', 'XboxAddictionz'), 24091),
#  (('Ceeday', 'PopularMMOs'), 24020),
#  (('Home Of Games', 'iTankid'), 24004),
#  (('Yammy', 'stacyplays'), 23956),
#  (('Grian', 'MagmaMusen'), 23954),
#  (('CaptainSparklez', 'Smosh Games'), 23952),
#  (('Preston', 'Thinknoodles'), 23942),
#  (('Ali-A', 'Denis'), 23924),
#  (('Doni Bobes', 'jacksepticeye'), 23924),
#  (('BCC Trolling', 'Fortnite Funny'), 23916),
#  (('PewDiePie', 'Please Stand By'), 23910),
#  (('GhostNinja', 'Sernandoe'), 23870),
#  (('Denis', 'SeeDeng'), 23835),
#  (('Kazok', 'PopularMMOs'), 23819),
#  (('Minecraft Universe', 'PewDiePie'), 23792),
#  (('PopularMMOs', 'ZexyZek'), 23786),
#  (('Markiplier', 'Nintendo'), 23785),
#  (('FusionZGamer', 'The Game Theorists'), 23782),
#  (('DanTDM', 'ShuffleGamer'), 23764),
#  (('Landon', 'Ninja'), 23757),
#  (('Ali-A', 'Miniminter'), 23744),
#  (('YOGSCAST Lewis & Sim...', 'jacksepticeye'), 23743),
#  (('Kiwiz', 'Lachlan'), 23740),
#  (('Thinknoodles', 'UnspeakableGaming'), 23723),
#  (('DanTDM', 'Home Of Games'), 23697),
#  (('Chief Pat', 'MOLT'), 23690),
#  (('Blitzwinger', 'DanTDM'), 23678),
#  (('DanTDM', 'MoreAliA'), 23648),
#  (('GameSpot', 'Nintendo'), 23599),
#  (('AntVenom', 'Please Stand By'), 23583),
#  (('DanTDM', 'Sub'), 23574),
#  (('Doni Bobes', 'Preston'), 23557),
#  (('Lachlan', 'The Game Theorists'), 23556),
#  (('CavemanFilms', 'Sky Does Everything'), 23553),
#  (('ShuffleGamer', 'iTankid'), 23544),
#  (('Sernandoe', 'jacksepticeye'), 23535),
#  (('Chaos', 'DanTDM'), 23525),
#  (('Little Donny - Minec...', 'Little Kelly Minecra...'), 23513),
#  (('ibxtoycat', 'jacksepticeye'), 23505),
#  (('Ali-A', 'PrestigeIsKey'), 23496),
#  (('Ali-A', 'TWOSYNC'), 23464),
#  (('Bajan Canadian', 'TheSyndicateProject'), 23451),
#  (('Fortnite Funny', 'Muselk'), 23445),
#  (('8-BitRyan', 'Markiplier'), 23433),
#  (('DashieGames', 'Markiplier'), 23385),
#  (('Denis', 'Markiplier'), 23361),
#  (('Buzz', 'jacksepticeye'), 23340),
#  (('Sketch', 'The Pals'), 23322),
#  (('Ninja', 'TheSmithPlays'), 23306),
#  (('PopularMMOs', 'Ryguyrocky'), 23297),
#  (('Ninja', 'SSundee'), 23283),
#  (('The Game Theorists', 'iHasCupquake'), 23283),
#  (('JeromeASF', 'MrWoofless'), 23282),
#  (('Aphmau', 'The Game Theorists'), 23278),
#  (('InquisitorMaster', 'cybernova games'), 23274),
#  (('Ali-A', 'XpertThief'), 23273),
#  (('TobyGames', 'UberHaxorNova'), 23272),
#  (('GTLive', 'Markiplier'), 23268),
#  (('Flamingo', 'SSundee'), 23245),
#  (('PewDiePie', 'Yandere Dev'), 23244),
#  (('VanossGaming', 'XboxAddictionz'), 23223),
#  (('League of Legends', 'Nightblue3'), 23199),
#  (('OfficialNerdCubed', 'YOGSCAST Lewis & Sim...'), 23174),
#  (('GhostNinja', 'TheSmithPlays'), 23170),
#  (('DanTDM', 'IGN'), 23152),
#  (('TheSyndicateProject', 'TobyGames'), 23144),
#  (('BeckBroJack', 'PopularMMOs'), 23135),
#  (('LazarBeam', 'Sernandoe'), 23131),
#  (('Lachlan', 'NoahsNoah'), 23119),
#  (('Duncan', 'Sips'), 23118),
#  (('FGTeeV', 'Flamingo'), 23117),
#  (('LeafyIsHere', 'Sky Does Everything'), 23107),
#  (('Markiplier', 'UnspeakableGaming'), 23106),
#  (('FGTeeV', 'Tofuu'), 23101),
#  (('Ali-A', 'Typical Gamer'), 23098),
#  (('Cizzorz', 'Muselk'), 23098),
#  (('LazarBeam', 'TBNRFrags'), 23054),
#  (('LazarBeam', 'Randumb'), 23044),
#  (('Formula', 'Kiwiz'), 22994),
#  (('CaRtOoNz', 'H2ODelirious'), 22992),
#  (('The Game Theorists', 'ibxtoycat'), 22982),
#  (('AshDubh', 'stampylonghead'), 22946),
#  (('LazarBeam', 'mrfreshasian'), 22945),
#  (('DanTDM', 'Gizzy Gazza'), 22923),
#  (('CaptainSparklez', 'TheAtlanticCraft'), 22917),
#  (('Poke', 'Sketch'), 22911),
#  (('JMX', 'MattHDGamer'), 22893),
#  (('GameSpot', 'YongYea'), 22892),
#  (('Ali-A', 'TheRelaxingEnd'), 22887),
#  (('DanTDM', 'Twine Cheeks'), 22875),
#  (('Bijuu Mike', 'Markiplier'), 22861),
#  (('Behzinga', 'Miniminter'), 22820),
#  (('InquisitorMaster', 'Jeruhmi'), 22795),
#  (('Bajan Canadian', 'TheAtlanticCraft'), 22793),
#  (('Kwebbelkop', 'PopularMMOs'), 22791),
#  (('League of Legends', 'videogamedunkey'), 22790),
#  (('DanTDM', 'Typical Gamer'), 22790),
#  (('PopularMMOs', 'ThnxCya'), 22780),
#  (('PopularMMOs', 'Sernandoe'), 22763),
#  (('The Game Theorists', 'UnspeakableGaming'), 22747),
#  (('Denis', 'RageElixir'), 22746),
#  (('Muselk', 'Top5Gaming'), 22727),
#  (('Calfreezy', 'W2S'), 22726),
#  (('Fandom Games', 'Markiplier'), 22707),
#  (('LispyJimmy', 'SSundee'), 22685),
#  (('Kazok', 'Poke'), 22679),
#  (('Tofuu', 'TwiistedPandora'), 22678),
#  (('Preston', 'TheCampingRusher - F...'), 22678),
#  (('YOGSCAST Lewis & Sim...', 'xXSlyFoxHoundXx'), 22665),
#  (('Ali-A', 'TobyGames'), 22654),
#  (('Jelly', 'PewDiePie'), 22649),
#  (('Ceeday', 'HJDoogan'), 22605),
#  (('DanTDM', 'JackFrostMiner'), 22601),
#  (('Denis', 'ZacharyZaxor'), 22587),
#  (('Logdotzip', 'Markiplier'), 22563),
#  (('DanTDM', 'Sqaishey Quack'), 22549),
#  (('SSundee', 'TheSyndicateProject'), 22545),
#  (('DanTDM', 'NoughtPointFourLIVE'), 22544),
#  (('JMX', 'TWOSYNC'), 22540),
#  (('KSI', 'W2S'), 22535),
#  (('Ali-A', 'JeromeASF'), 22518),
#  (('IGN', 'outsidexbox'), 22489),
#  (('PewDiePie', 'PlayStation'), 22483),
#  (('Crainer', 'The Game Theorists'), 22479),
#  (('JeromeASF', 'Minecraft Universe'), 22475),
#  (('Poke', 'VuxVux'), 22467),
#  (('8-BitGaming', 'Markiplier'), 22433),
#  (('Muselk', 'Twine Cheeks'), 22432),
#  (('H2ODelirious', 'Sky Does Everything'), 22402),
#  (('Kiwiz', 'Randumb'), 22342),
#  (('AntVenom', 'SethBling'), 22342),
#  (('DanTDM', 'SeeDeng'), 22321),
#  (('LispyJimmy', 'PewDiePie'), 22316),
#  (('OfficialNerdCubed', 'PewDiePie'), 22311),
#  (('DanTDM', 'TBNRFrags'), 22302),
#  (('WhiteBoy7thst', 'YOGSCAST Lewis & Sim...'), 22271),
#  (('BigFoltz', 'Lachlan'), 22270),
#  (('GameGrumps', 'IGN'), 22255),
#  (('PopularMMOs', 'theRadBrad'), 22254),
#  (('Jelly', 'LazarBeam'), 22229),
#  (('Bajan Canadian', 'Markiplier'), 22225),
#  ...]

# %%
edges_pldf = pl.DataFrame({
    'channel1': [edge[0][0] for edge in sorted_edges],
    'channel2': [edge[0][1] for edge in sorted_edges],
    'weight': [edge[1] for edge in sorted_edges]
})

# uncomment to save the edges
edges_pldf.write_csv('../data/channels_edges.csv')

# %%
# # Polars version (doesn't work on full dataset)

# comments_video_game = comments_df.join(joined_df.lazy(), left_on='video_id', right_on='display_id')
# comments_channels = comments_video_game.select([
#     pl.col('author'),
#     pl.col('video_game')
# ]).unique()

# counts_per_author = (
#     comments_game_df
#     .group_by("author")
#     .agg(pl.col("video_game").count().alias("count"))
#     .filter(pl.col("count") > 1)
# )

# comments_several_channels = comments_game_df.join(counts_per_author, on="author", how="inner").select(['author', 'video_game'])

# pairs = comments_several_channels.join(comments_several_channels, on="author", how="inner").filter(pl.col('video_game') < pl.col('video_game_right')).select(['video_game', 'video_game_right'])

# pairs_grouped = pairs.group_by(['video_game', 'video_game_right']).agg(pl.col('video_game').count().alias('weight')).sort('weight', descending=True)

# pairs_grouped.collect()

# %% [markdown]
# ### Weight adjustment and filtering

# %%
def adjust_weight(edges: pl.DataFrame, popularity: dict, threshold: int, alpha: float, beta: float = 1.0) -> dict:
    adjusted_edges = {}
    for edge in edges.iter_rows():
        game1, game2, weight = edge
        # Get the popularity of the games
        p1 = popularity[game1]
        p2 = popularity[game2]
        # Adjust the weight using the formula
        adjusted_weight = int((weight ** beta) * ((min(p1, p2) / max(p1, p2)) ** alpha))
        if adjusted_weight > threshold:
            adjusted_edges[(game1, game2)] = adjusted_weight
    return adjusted_edges

# %%
edges = pl.read_csv("../data/games_edges_all.csv")
popularity = dict(zip(games_count["video_game"], games_count["count"]))
alpha = 0.5
beta = 0.75
threshold = 5000

adjusted_edges = adjust_weight(edges, popularity, threshold, alpha, beta)


edges_dict = {}
for edge in edges.iter_rows():
    game1, game2, weight = edge
    edges_dict[(game1, game2)] = weight

unique_games = set()
for edge in adjusted_edges:
    unique_games.add(edge[0])
    unique_games.add(edge[1])
    
print(f'After filtering : {len(adjusted_edges)} edges and {len(unique_games)} nodes')

print(f'Before adjustment ({len(edges_dict)} edges)')
print(f'fortnite -> minecraft: {edges_dict[("fortnite", "minecraft")]}')
print(f'fifa 14 -> minecraft: {edges_dict[("fifa 14", "minecraft")]}')
print(f'fifa 14 -> fifa 15: {edges_dict[("fifa 14", "fifa 15")]}')

print(f'After adjustment ({len(adjusted_edges)} edges)')
print(f'fortnite -> minecraft: {adjusted_edges[("fortnite", "minecraft")]} if ("fortnite", "minecraft") in adjusted_edges else 0')
print(f'fifa 14 -> minecraft: {adjusted_edges[("fifa 14", "minecraft")] if ("fifa 14", "minecraft") in adjusted_edges else 0}')
print(f'fifa 14 -> fifa 15: {adjusted_edges[("fifa 14", "fifa 15")] if ("fifa 14", "fifa 15") in adjusted_edges else 0}')
# Out:
# After filtering : 916 edges and 119 nodes
# Before adjustment (540605 edges)
# fortnite -> minecraft: 8238018
# fifa 14 -> minecraft: 437157
# fifa 14 -> fifa 15: 433682
# After adjustment (916 edges)
# fortnite -> minecraft: 107912 if ("fortnite", "minecraft") in adjusted_edges else 0
# fifa 14 -> minecraft: 0
# fifa 14 -> fifa 15: 15747

# %%
import networkx as nx
import community as community_louvain  # Install via `pip install python-louvain`
import json

# Example input (edges list with weights after adjustment)

# Create graph
G = nx.Graph()
for (source, target), weight in adjusted_edges.items():
    G.add_edge(source, target, weight=weight)

# Create node_size which is the popularity of the game divided by 2000

# # Compute positions using Fruchterman-Reingold (spring layout)
positions = nx.forceatlas2_layout(G, max_iter=500, seed=42, dissuade_hubs=True, jitter_tolerance=0.6, gravity=50)

# Community detection using Louvain method
partition = community_louvain.best_partition(G, random_state=42)

# Prepare nodes and edges for JSON output
nodes = []
node_map = {}  # Maps node names to IDs
for i, (node, pos) in enumerate(positions.items()):
    node_map[node] = str(i)
    pop = popularity[node]
    nodes.append({
        "id": str(i),
        "name": node,
        "x": pos[0] * 1000,  # Scale positions for better visualization
        "y": pos[1] * 1000,
        "symbolSize": (pop / 2000) ** 0.5,  # Example: size proportional to degree
        "value": pop,
        "category": partition[node]
    })

edges = [
    {"source": node_map[source], "target": node_map[target]}
    for source, target in G.edges()
]

categories = [
    {"name": name}
    for name in set(partition.values())
]

# Output JSON
output = {
    "nodes": nodes,
    "edges": edges,
    "categories": categories
}

print(f'Number of nodes in the network: {len(nodes)}')
print(f'Number of edges in the network: {len(edges)}')
print(f'Number of communities in the network: {len(categories)}')

# Save to file
with open('../website/data/games_network.json', 'w') as f:
    json.dump(output, f, indent=2)
# Out:
# Number of nodes in the network: 119
# Number of edges in the network: 916
# Number of communities in the network: 5

# %% [markdown]
# ## Channels network

# %%
edges_channels = pl.read_csv('../data/channels_edges.csv')
channels_df = pl.read_csv('../data/youniverse/filtered/gaming_channels.tsv', separator='\t')

popularity_channels = dict(zip(channels_df['channel_name'], channels_df['subscribers']))

# %%
alpha = 0.6
beta = 0.8
threshold = 800

adjusted_edges = adjust_weight(edges_channels, popularity_channels, threshold, alpha, beta)

# %%
unique_channels = set()
for edge in adjusted_edges:
    unique_channels.add(edge[0])
    unique_channels.add(edge[1])

print(f'Before adjustment: {len(edges_channels)} edges')
print(f'Edges: {len(adjusted_edges)}, Nodes: {len(unique_channels)}')
# Out:
# Before adjustment: 46459899 edges
# Edges: 5840, Nodes: 695

# %%
import networkx as nx
import community as community_louvain  # Install via `pip install python-louvain`
import json


# Create graph
G = nx.Graph()
for (source, target), weight in adjusted_edges.items():
    G.add_edge(source, target, weight=weight)
    

# Create node_size which is the popularity of the game divided by 2000

# # Compute positions using Fruchterman-Reingold (spring layout)
positions = nx.forceatlas2_layout(G, max_iter=500, seed=42, dissuade_hubs=True, jitter_tolerance=0.6, gravity=50)

# Community detection using Louvain method
partition = community_louvain.best_partition(G, random_state=42)

# Prepare nodes and edges for JSON output
nodes = []
node_map = {}  # Maps node names to IDs
for i, (node, pos) in enumerate(positions.items()):
    node_map[node] = str(i)
    pop = popularity_channels[node]

    nodes.append({
        "id": str(i),
        "name": node,
        "x": pos[0] * 1000,  # Scale positions for better visualization
        "y": pos[1] * 1000,
        "symbolSize": (pop / 100000) ** 0.4,  # Example: size proportional to degree
        "value": pop,
        "category": partition[node]
    })

edges = [
    {"source": node_map[source], "target": node_map[target]}
    for source, target in G.edges()
]

categories = [
    {"name": name}
    for name in set(partition.values())
]

# Output JSON
output = {
    "nodes": nodes,
    "edges": edges,
    "categories": categories
}

print(f'Number of nodes in the network: {len(nodes)}')
print(f'Number of edges in the network: {len(edges)}')
print(f'Number of communities in the network: {len(categories)}')

# Save to file
with open('../website/data/channels_network.json', 'w') as f:
    json.dump(output, f, indent=2)
# Out:
# Number of nodes in the network: 695
# Number of edges in the network: 5840
# Number of communities in the network: 34
