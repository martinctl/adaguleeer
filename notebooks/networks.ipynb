# %%
import polars as pl

# %%
COMMENTS_PATH = '/Users/martinctl/Developer/EPFL/MA1/ada/project-data/gaming_comments.parquet'
COMMENTS_PATH_GAMES = '/Users/martinctl/Developer/EPFL/MA1/ada/project-data/gaming_comments_with_games.parquet'

# videos_df = pl.read_csv('../data/youniverse/filtered/gaming_videos_with_games.tsv', separator='\t')
# comments_df = pl.read_csv('../data/youniverse/filtered/gaming_comments.tsv', separator='\t')
videos_df = pl.read_parquet('/Users/martinctl/Developer/EPFL/MA1/ada/project-data/gaming_videos_with_games.parquet')

# %%
comments_df = pl.scan_parquet(COMMENTS_PATH)
comments_df.head(5).collect()
# Out:
# shape: (5, 2)
# ┌────────┬─────────────┐
# │ author ┆ video_id    │
# │ ---    ┆ ---         │
# │ i64    ┆ str         │
# ╞════════╪═════════════╡
# │ 2      ┆ 9pQILRT42Cg │
# │ 2      ┆ PWWRzCyuiFU │
# │ 5      ┆ 9MuGpmXGlsY │
# │ 5      ┆ UvZPbfUkMGw │
# │ 11     ┆ qj9sjQjQ19M │
# └────────┴─────────────┘

# %%
games_count = videos_df.group_by('video_game').agg(pl.count('video_game').alias('count')).sort('count', descending=True)
games_count
# Out:
# shape: (1_064, 2)
# ┌─────────────────────────────────┬────────┐
# │ video_game                      ┆ count  │
# │ ---                             ┆ ---    │
# │ str                             ┆ u32    │
# ╞═════════════════════════════════╪════════╡
# │ minecraft                       ┆ 766154 │
# │ fortnite                        ┆ 377337 │
# │ call of duty                    ┆ 368658 │
# │ league of legends               ┆ 236065 │
# │ roblox                          ┆ 205762 │
# │ …                               ┆ …      │
# │ pokémon unite                   ┆ 2      │
# │ the great ace attorney adventu… ┆ 2      │
# │ road 96                         ┆ 1      │
# │ triangle strategy               ┆ 1      │
# │ dr kawashimas brain training h… ┆ 1      │
# └─────────────────────────────────┴────────┘

# %%
# Get only the display_id and video_game columns
joined_df = videos_df.select([
    pl.col('display_id'),
    pl.col('video_game'),
])
joined_df

# Create a set of mappings from display_id to video_game
df = joined_df.to_pandas()
videos = pl.Series('video_id', joined_df.select(pl.col('display_id')))
display_id_to_game = dict(zip(df['display_id'], df['video_game']))

def get_game(display_id: str):
    return display_id_to_game.get(display_id, None)

# %%
# import random
# import time

# random.seed(42)
# random_display_id = random.sample(list(display_id_to_game.keys()), 1_000_000)

# start = time.time()
# for display_id in random_display_id:
#     get_game(display_id)
    
# print((time.time() - start) * 2000, 's')

# %%
comments_valid = comments_df.filter(pl.col('video_id').is_in(videos))

comments_game = comments_valid.with_columns(pl.col('video_id').map_elements(get_game, return_dtype=str))

# # We can now save the comments with the game
# comments_game.sink_parquet('/Users/martinctl/Developer/EPFL/MA1/ada/project-data/gaming_comments_with_games.parquet')

comments_game_df = (pl.scan_parquet(COMMENTS_PATH_GAMES, n_rows=100_000_000)).unique()

# %%
from itertools import combinations
from tqdm import tqdm

# ! Take 30 minutes to run

def get_edges(comments):
    rows = comments.shape[0]
    
    curr_author = None
    games = set()
    edges = {}
    authors = 0

    for com in tqdm(comments.iter_rows(), total=rows):
        author, game = com
        if author != curr_author:
            curr_author = author
            if len(games) > 1:
                for edge in combinations(games, 2):
                    edge = tuple(sorted(edge))
                    edges[edge] = edges.get(edge, 0) + 1
            games = set()
            authors += 1

        games.add(game)
    
    return sorted(edges.items(), key=lambda x: x[1], reverse=True)

sorted_edges = get_edges(pl.read_parquet(COMMENTS_PATH_GAMES))
sorted_edges
# Out:
# 100%|██████████| 1369135342/1369135342 [30:03<00:00, 759362.86it/s]
# [(('fortnite', 'minecraft'), 8238018),
#  (('minecraft', 'roblox'), 7883337),
#  (('call of duty', 'minecraft'), 5680816),
#  (('grand theft auto', 'minecraft'), 5109961),
#  (('fortnite', 'roblox'), 4295719),
#  (('call of duty', 'fortnite'), 3848304),
#  (('five nights at freddys', 'minecraft'), 3805796),
#  (('call of duty', 'grand theft auto'), 3583126),
#  (('fortnite', 'grand theft auto'), 3274580),
#  (('garrys mod', 'minecraft'), 2791642),
#  (('minecraft', 'the sims'), 2530688),
#  (('happy wheels', 'minecraft'), 2356728),
#  (('five nights at freddys', 'roblox'), 1742120),
#  (('grand theft auto', 'roblox'), 1675014),
#  (('five nights at freddys', 'fortnite'), 1573621),
#  (('hello neighbor', 'minecraft'), 1511571),
#  (('minecraft', 'yandere simulator'), 1506154),
#  (('league of legends', 'minecraft'), 1503122),
#  (('clash royale', 'minecraft'), 1502185),
#  (('clash of clans', 'minecraft'), 1497485),
#  (('call of duty', 'garrys mod'), 1492649),
#  (('garrys mod', 'grand theft auto'), 1492326),
#  (('counterstrike', 'minecraft'), 1490445),
#  (('minecraft', 'undertale'), 1477204),
#  (('minecraft', 'super smash bros'), 1301299),
#  (('clash royale', 'fortnite'), 1265308),
#  (('five nights at freddys', 'grand theft auto'), 1214222),
#  (('roblox', 'the sims'), 1196785),
#  (('call of duty', 'roblox'), 1193296),
#  (('call of duty', 'five nights at freddys'), 1186980),
#  (('call of duty', 'counterstrike'), 1182627),
#  (('fortnite', 'garrys mod'), 1179821),
#  (('minecraft', 'subnautica'), 1173375),
#  (('five nights at freddys', 'garrys mod'), 1131231),
#  (('minecraft', 'spiderman'), 1129790),
#  (('grand theft auto', 'happy wheels'), 1128141),
#  (('hello neighbor', 'roblox'), 1122729),
#  (('call of duty', 'happy wheels'), 1116347),
#  (('ark survival evolved', 'minecraft'), 1080012),
#  (('assassins creed', 'minecraft'), 1074586),
#  (('minecraft', 'resident evil'), 1066810),
#  (('clash of clans', 'fortnite'), 1044152),
#  (('fallout 4', 'minecraft'), 1018861),
#  (('minecraft', 'super mario maker'), 999605),
#  (('assassins creed', 'call of duty'), 991061),
#  (('fear', 'minecraft'), 953594),
#  (('call of duty', 'league of legends'), 953444),
#  (('roblox', 'yandere simulator'), 951786),
#  (('agario', 'minecraft'), 950348),
#  (('minecraft', 'slitherio'), 944865),
#  (('far cry', 'minecraft'), 938141),
#  (('minecraft', 'mortal kombat'), 932023),
#  (('minecraft', 'team fortress 2'), 924383),
#  (('garrys mod', 'roblox'), 907128),
#  (('fortnite', 'spiderman'), 894626),
#  (('fortnite', 'hello neighbor'), 894602),
#  (('call of duty', 'undertale'), 409726),
#  (('agario', 'grand theft auto'), 409059),
#  (('counterstrike', 'five nights at freddys'), 407071),
#  (('fallout 4', 'garrys mod'), 405238),
#  (('fortnite', 'hitman'), 403373),
#  (('fear', 'five nights at freddys'), 402572),
#  (('assassins creed', 'far cry'), 400748),
#  (('crash bandicoot', 'minecraft'), 400243),
#  (('fifa 17', 'grand theft auto'), 400040),
#  (('fortnite', 'god of war'), 397585),
#  (('garrys mod', 'subnautica'), 396942),
#  (('minecraft', 'need for speed'), 396550),
#  (('dead rising', 'minecraft'), 396277),
#  (('call of duty', 'final fantasy'), 395884),
#  (('five nights at freddys', 'team fortress 2'), 393920),
#  (('call of duty', 'the elder scrolls v skyrim'), 392791),
#  (('fallout 76', 'minecraft'), 391268),
#  (('minecraft', 'titanfall'), 388159),
#  (('roblox', 'totally accurate battle simulator'), 388074),
#  (('fortnite', 'pokémon go'), 386547),
#  (('garrys mod', 'team fortress 2'), 383188),
#  (('dont starve', 'minecraft'), 383082),
#  (('fortnite', 'forza horizon'), 381273),
#  (('fallout 4', 'five nights at freddys'), 380655),
#  (('far cry', 'garrys mod'), 380260),
#  (('the sims', 'undertale'), 379001),
#  (('agario', 'call of duty'), 378315),
#  (('roblox', 'super mario maker'), 378103),
#  (('five nights at freddys', 'ultimate custom night'), 377994),
#  (('garrys mod', 'super smash bros'), 377690),
#  (('fallout 76', 'fortnite'), 375031),
#  (('call of duty', 'tom clancys rainbow six siege'), 374831),
#  (('call of duty', 'until dawn'), 373908),
#  (('minecraft', 'super mario 64'), 373224),
#  (('assassins creed', 'garrys mod'), 372872),
#  (('call of duty', 'fallout 76'), 372384),
#  (('minecraft', 'slime rancher'), 372028),
#  (('kingdom hearts', 'minecraft'), 371556),
#  (('five nights at freddys', 'the legend of zelda'), 370979),
#  (('happy wheels', 'undertale'), 370352),
#  (('garrys mod', 'resident evil'), 369557),
#  (('agario', 'roblox'), 369397),
#  (('for honor', 'minecraft'), 369018),
#  (('fortnite', 'mario bros'), 368925),
#  (('mortal kombat', 'resident evil'), 367862),
#  (('battlefield v', 'grand theft auto'), 367190),
#  (('grand theft auto', 'the legend of zelda'), 363707),
#  (('fortnite', 'tom clancys rainbow six siege'), 363703),
#  (('grand theft auto', 'skate 3'), 361323),
#  (('grand theft auto', 'yandere simulator'), 360845),
#  (('destiny 2', 'grand theft auto'), 360013),
#  (('kerbal space program', 'minecraft'), 359709),
#  (('minecraft', 'scribblenauts'), 358891),
#  (('fortnite', 'mario kart 8'), 357959),
#  (('call of duty', 'hello neighbor'), 357455),
#  (('agario', 'five nights at freddys'), 356730),
#  (('assassins creed', 'resident evil'), 356664),
#  (('counterstrike', 'happy wheels'), 356532),
#  (('deadpool', 'minecraft'), 355894),
#  (('hello neighbor', 'yandere simulator'), 354540),
#  (('call of duty', 'for honor'), 353454),
#  (('injustice 2', 'minecraft'), 353116),
#  (('dying light', 'minecraft'), 352933),
#  (('sonic the hedgehog', 'super smash bros'), 352696),
#  (('dragon ball xenoverse', 'minecraft'), 352424),
#  (('fortnite', 'splatoon'), 316937),
#  (('clash of clans', 'five nights at freddys'), 316658),
#  (('call of duty', 'halo 4'), 316139),
#  (('fear', 'happy wheels'), 315477),
#  (('grand theft auto', 'the elder scrolls v skyrim'), 315273),
#  (('gang beasts', 'roblox'), 315244),
#  (('happy wheels', 'super mario maker'), 314894),
#  (('dota 2', 'minecraft'), 314765),
#  (('five nights at freddys', 'league of legends'), 314371),
#  (('mortal kombat', 'super smash bros'), 314257),
#  (('mario bros', 'super mario maker'), 313713),
#  (('minecraft', 'pokémon sun'), 313570),
#  (('mario bros', 'the legend of zelda'), 313406),
#  (('dark souls', 'five nights at freddys'), 312904),
#  (('geometry dash', 'grand theft auto'), 312698),
#  (('call of duty', 'sonic the hedgehog'), 312447),
#  (('fortnite', 'gang beasts'), 312376),
#  (('dark souls', 'garrys mod'), 312141),
#  (('mega man', 'minecraft'), 312126),
#  (('spiderman', 'super smash bros'), 312102),
#  (('club penguin', 'minecraft'), 311924),
#  (('call of duty', 'the forest'), 311672),
#  (('fallout 4', 'resident evil'), 310292),
#  (('fallout 4', 'fallout 76'), 310225),
#  (('call of duty', 'injustice 2'), 309537),
#  (('five nights at freddys', 'until dawn'), 309203),
#  (('call of duty', 'dying light'), 309194),
#  (('far cry', 'resident evil'), 308878),
#  (('dead by daylight', 'grand theft auto'), 308826),
#  (('assassins creed', 'five nights at freddys'), 308659),
#  (('fifa 14', 'grand theft auto'), 308556),
#  (('super mario maker', 'the legend of zelda'), 307930),
#  (('mortal kombat', 'spiderman'), 307320),
#  (('five nights at freddys', 'mario kart 8'), 306934),
#  (('resident evil', 'roblox'), 306703),
#  (('clash royale', 'five nights at freddys'), 306441),
#  (('far cry', 'five nights at freddys'), 306332),
#  (('resident evil', 'super smash bros'), 306092),
#  (('happy wheels', 'super smash bros'), 305830),
#  (('league of legends', 'super smash bros'), 303859),
#  (('counterstrike', 'roblox'), 303775),
#  (('dead rising', 'grand theft auto'), 303555),
#  (('grand theft auto', 'mario bros'), 303542),
#  (('minecraft', 'surgeon simulator 2013'), 303113),
#  (('flappy bird', 'minecraft'), 303021),
#  (('call of duty', 'plants vs zombies'), 302488),
#  (('splatoon', 'super smash bros'), 302382),
#  (('call of duty', 'gears of war'), 302344),
#  (('battlefield 3', 'grand theft auto'), 302309),
#  (('battlefield 3', 'battlefield 4'), 301585),
#  (('grand theft auto', 'titanfall'), 301388),
#  (('call of duty', 'no mans sky'), 301348),
#  (('doki doki literature club', 'roblox'), 301254),
#  (('call of duty', 'tomb raider'), 299992),
#  (('final fantasy', 'grand theft auto'), 299732),
#  (('bioshock', 'minecraft'), 299549),
#  (('call of duty', 'yandere simulator'), 299387),
#  (('battlefield 1', 'battlefield 4'), 299313),
#  (('fortnite', 'skate 3'), 299076),
#  (('fifa 19', 'minecraft'), 298496),
#  (('minecraft', 'street fighter'), 298451),
#  (('five nights at freddys', 'totally accurate battle simulator'), 298276),
#  (('grand theft auto', 'world of warcraft'), 297821),
#  (('human fall flat', 'roblox'), 297273),
#  (('borderlands 2', 'minecraft'), 297150),
#  (('assassins creed', 'mortal kombat'), 297062),
#  (('fifa 18', 'minecraft'), 296677),
#  (('red dead redemption', 'resident evil'), 296292),
#  (('fifa 17', 'fifa 19'), 295926),
#  (('little nightmares', 'minecraft'), 295732),
#  (('call of duty', 'mass effect'), 295546),
#  (('among us', 'call of duty'), 294862),
#  (('battlefield 1', 'counterstrike'), 294212),
#  (('garrys mod', 'super mario maker'), 294115),
#  (('7 days to die', 'minecraft'), 293892),
#  (('assassins creed', 'dark souls'), 293886),
#  (('assassins creed', 'league of legends'), 293574),
#  (('fallout new vegas', 'minecraft'), 293177),
#  (('far cry', 'red dead redemption'), 292955),
#  (('dark souls', 'super smash bros'), 292648),
#  (('counterstrike', 'team fortress 2'), 292419),
#  (('red dead redemption', 'spiderman'), 292017),
#  (('fortnite', 'the forest'), 291900),
#  (('mario kart 8', 'super smash bros'), 290939),
#  (('happy wheels', 'league of legends'), 290682),
#  (('hello neighbor', 'the sims'), 290611),
#  (('minecraft', 'tomb raider'), 290610),
#  (('grand theft auto', 'sonic the hedgehog'), 290153),
#  (('happy wheels', 'mortal kombat'), 290139),
#  (('call of duty', 'street fighter'), 289857),
#  (('roblox', 'team fortress 2'), 289111),
#  (('battlefield 4', 'fortnite'), 289065),
#  (('gang beasts', 'grand theft auto'), 289057),
#  (('garrys mod', 'the last of us'), 288791),
#  (('fifa 16', 'fifa 18'), 288646),
#  (('fallout 4', 'red dead redemption'), 288620),
#  (('call of duty', 'slitherio'), 288546),
#  (('happy wheels', 'spiderman'), 287715),
#  (('the legend of zelda', 'undertale'), 287517),
#  (('roblox', 'super mario odyssey'), 287256),
#  (('battlefield 1', 'battlefield v'), 287164),
#  (('mass effect', 'minecraft'), 286916),
#  (('minecraft', 'silent hill'), 286790),
#  (('call of duty', 'detroit become human'), 286682),
#  (('fifa 15', 'fortnite'), 286613),
#  (('fortnite', 'until dawn'), 285579),
#  (('call of duty', 'totally accurate battle simulator'), 284667),
#  (('minecraft', 'warframe'), 284028),
#  (('call of duty', 'vrchat'), 283989),
#  (('metroid', 'minecraft'), 282370),
#  (('mortal kombat', 'roblox'), 282105),
#  (('fortnite', 'world of warcraft'), 281703),
#  (('beyond two souls', 'minecraft'), 280775),
#  (('plants vs zombies', 'roblox'), 279871),
#  (('subnautica', 'undertale'), 279818),
#  (('borderlands 2', 'call of duty'), 279769),
#  (('fallout 76', 'grand theft auto'), 279287),
#  (('assassins creed', 'counterstrike'), 279131),
#  (('minecraft', 'the binding of isaac'), 279029),
#  (('dying light', 'grand theft auto'), 278766),
#  (('detroit become human', 'grand theft auto'), 278664),
#  (('grand theft auto', 'left 4 dead'), 277791),
#  (('grand theft auto', 'tom clancys rainbow six siege'), 277525),
#  (('battlefield 1', 'fallout 4'), 277368),
#  (('roblox', 'ultimate custom night'), 276881),
#  (('final fantasy', 'resident evil'), 276390),
#  (('sonic the hedgehog', 'the legend of zelda'), 275494),
#  (('fallout 4', 'happy wheels'), 275175),
#  (('assassins creed', 'the last of us'), 275127),
#  (('fortnite', 'the last of us'), 275011),
#  (('happy wheels', 'team fortress 2'), 274592),
#  (('fortnite', 'sea of thieves'), 273718),
#  (('counterstrike', 'far cry'), 273590),
#  (('mario kart 8', 'super mario maker'), 272238),
#  (('among us', 'grand theft auto'), 271910),
#  (('fortnite', 'life is strange'), 271053),
#  (('assassins creed', 'watch dogs'), 271050),
#  (('final fantasy', 'fortnite'), 270555),
#  (('battlefield 4', 'counterstrike'), 270268),
#  (('five nights at freddys', 'life is strange'), 269827),
#  (('fortnite', 'need for speed'), 269242),
#  (('minecraft', 'sea of thieves'), 269201),
#  (('final fantasy', 'super smash bros'), 268816),
#  (('dragon ball xenoverse', 'fortnite'), 268708),
#  (('ark survival evolved', 'garrys mod'), 268337),
#  (('doki doki literature club', 'yandere simulator'), 268154),
#  (('counterstrike', 'dark souls'), 268133),
#  (('mario party', 'super smash bros'), 268093),
#  (('five nights at freddys', 'super mario odyssey'), 267516),
#  (('grand theft auto', 'life is strange'), 267020),
#  (('halflife', 'minecraft'), 266612),
#  (('call of duty', 'kingdom hearts'), 266355),
#  (('animal crossing', 'minecraft'), 266063),
#  (('amnesia the dark descent', 'minecraft'), 266044),
#  (('iron man', 'minecraft'), 265960),
#  (('batman arkham knight', 'minecraft'), 265263),
#  (('agario', 'happy wheels'), 265082),
#  (('battlefield 4', 'garrys mod'), 263983),
#  (('fear', 'resident evil'), 263410),
#  (('for honor', 'grand theft auto'), 263045),
#  (('gears of war', 'minecraft'), 262963),
#  (('call of duty', 'portal 2'), 262455),
#  (('league of legends', 'resident evil'), 262381),
#  (('grand theft auto', 'vrchat'), 262259),
#  (('dead space', 'minecraft'), 261834),
#  (('final fantasy', 'the legend of zelda'), 261596),
#  (('call of duty', 'halo reach'), 261325),
#  (('resident evil', 'the legend of zelda'), 261239),
#  (('friday the 13th the game', 'minecraft'), 260950),
#  (('assassins creed', 'battlefield 4'), 260004),
#  (('minecraft', 'super mario galaxy'), 259448),
#  (('akinator', 'roblox'), 259287),
#  (('counterstrike', 'resident evil'), 258695),
#  (('resident evil', 'subnautica'), 258651),
#  (('hello neighbor', 'subnautica'), 257943),
#  (('battlefield 1', 'garrys mod'), 257316),
#  (('happy wheels', 'the last of us'), 256612),
#  (('god of war', 'resident evil'), 256504),
#  (('minecraft', 'paper mario'), 254902),
#  (('dark souls', 'the legend of zelda'), 254571),
#  (('batman arkham knight', 'call of duty'), 254391),
#  (('fallout 4', 'the elder scrolls v skyrim'), 254134),
#  (('super mario maker', 'super mario odyssey'), 254037),
#  (('halo reach', 'minecraft'), 253767),
#  (('super mario 64', 'super smash bros'), 253502),
#  (('far cry', 'spiderman'), 253305),
#  (('grand theft auto', 'no mans sky'), 253297),
#  (('bioshock', 'call of duty'), 253006),
#  (('super smash bros', 'team fortress 2'), 252788),
#  (('five nights at freddys', 'plants vs zombies'), 252778),
#  (('fallout 4', 'star wars battlefront'), 252772),
#  (('grand theft auto', 'plants vs zombies'), 252754),
#  (('agario', 'garrys mod'), 252747),
#  (('league of legends', 'roblox'), 252745),
#  (('metal gear', 'resident evil'), 252236),
#  (('minecraft', 'pacman'), 235868),
#  (('beat saber', 'minecraft'), 235668),
#  (('call of duty', 'dead space'), 235659),
#  (('dead by daylight', 'five nights at freddys'), 235574),
#  (('fallout 4', 'spiderman'), 235556),
#  (('mortal kombat', 'red dead redemption'), 235519),
#  (('detroit become human', 'roblox'), 235218),
#  (('batman arkham knight', 'grand theft auto'), 234350),
#  (('dota 2', 'league of legends'), 234327),
#  (('golf with your friends', 'minecraft'), 234254),
#  (('fortnite', 'the escapists'), 233801),
#  (('kingdom hearts', 'super smash bros'), 233777),
#  (('dark souls', 'mortal kombat'), 233407),
#  (('fallout 4', 'league of legends'), 233203),
#  (('league of legends', 'mortal kombat'), 232476),
#  (('dark souls', 'far cry'), 231622),
#  (('league of legends', 'team fortress 2'), 231464),
#  (('ark survival evolved', 'subnautica'), 231398),
#  (('fortnite', 'mario party'), 231299),
#  (('fallout 76', 'red dead redemption'), 231218),
#  (('clash of clans', 'counterstrike'), 230530),
#  (('akinator', 'five nights at freddys'), 230394),
#  (('fortnite', 'friday the 13th the game'), 230276),
#  (('resident evil', 'super mario maker'), 230153),
#  (('assassins creed', 'final fantasy'), 229986),
#  (('resident evil', 'the sims'), 229861),
#  (('counterstrike', 'super smash bros'), 229553),
#  (('garrys mod', 'the forest'), 229414),
#  (('fallout 4', 'super smash bros'), 228059),
#  (('call of duty', 'dragon ball xenoverse'), 228019),
#  (('geometry dash', 'hello neighbor'), 227877),
#  (('hello neighbor', 'resident evil'), 227748),
#  (('roblox', 'sonic the hedgehog'), 227732),
#  (('fallout 4', 'subnautica'), 227655),
#  (('sonic the hedgehog', 'super mario maker'), 227483),
#  (('roblox', 'the legend of zelda'), 227082),
#  (('garrys mod', 'until dawn'), 226654),
#  (('garrys mod', 'rocket league'), 225777),
#  (('battlefield 4', 'far cry'), 225613),
#  (('roblox', 'the escapists'), 225209),
#  (('splatoon', 'the legend of zelda'), 225208),
#  (('minecraft', 'prison architect'), 224874),
#  (('grand theft auto', 'mass effect'), 224281),
#  (('happy wheels', 'totally accurate battle simulator'), 224147),
#  (('fortnite', 'no mans sky'), 223810),
#  (('five nights at freddys', 'the escapists'), 223525),
#  (('five nights at freddys', 'the forest'), 223386),
#  (('spiderman', 'the legend of zelda'), 222989),
#  (('borderlands 3', 'call of duty'), 222887),
#  (('fallout 4', 'roblox'), 222631),
#  (('akinator', 'fortnite'), 222536),
#  (('call of duty', 'super mario odyssey'), 222523),
#  (('grand theft auto', 'kerbal space program'), 222339),
#  (('dying light', 'fortnite'), 221916),
#  (('hitman', 'resident evil'), 221773),
#  (('spiderman', 'undertale'), 221698),
#  (('bloodborne', 'minecraft'), 221421),
#  (('heavy rain', 'minecraft'), 221277),
#  (('clash of clans', 'happy wheels'), 220649),
#  (('garrys mod', 'star wars battlefront'), 220565),
#  (('garrys mod', 'sonic the hedgehog'), 220110),
#  (('metroid', 'super smash bros'), 220086),
#  (('dark souls', 'metal gear'), 219853),
#  (('clash of clans', 'league of legends'), 219841),
#  (('bloodborne', 'dark souls'), 219669),
#  (('assassins creed', 'the legend of zelda'), 218922),
#  (('five nights at freddys', 'goat simulator'), 218587),
#  (('minecraft', 'south park the stick of truth'), 218411),
#  (('grand theft auto', 'portal 2'), 218338),
#  (('fallout 4', 'the sims'), 218276),
#  (('call of duty', 'crash bandicoot'), 217913),
#  (('dark souls', 'spiderman'), 217900),
#  (('pokémon go', 'roblox'), 217631),
#  (('garrys mod', 'watch dogs'), 217465),
#  (('call of duty', 'fifa 19'), 217319),
#  (('garrys mod', 'skate 3'), 217295),
#  (('mario bros', 'super mario odyssey'), 217156),
#  (('happy wheels', 'the legend of zelda'), 217141),
#  (('call of duty', 'halo 5 guardians'), 217110),
#  (('minecraft', 'stardew valley'), 217042),
#  (('fifa 16', 'fifa 19'), 216747),
#  (('fallout 4', 'fallout new vegas'), 216659),
#  (('fallout 4', 'metal gear'), 216526),
#  (('super mario odyssey', 'undertale'), 216289),
#  (('assassins creed', 'the sims'), 216247),
#  (('assassins creed', 'the elder scrolls v skyrim'), 215960),
#  (('happy wheels', 'mario kart 8'), 215914),
#  (('fortnite', 'warframe'), 215746),
#  (('borderlands 3', 'minecraft'), 215718),
#  (('five nights at freddys', 'hitman'), 215709),
#  (('far cry', 'the last of us'), 215605),
#  (('fear', 'undertale'), 215355),
#  (('battlefield 1', 'red dead redemption'), 215225),
#  (('spiderman', 'the sims'), 214878),
#  (('minecraft', 'tetris'), 214733),
#  (('battlefield v', 'red dead redemption'), 214000),
#  (('minecraft', 'shadow of the colossus'), 213909),
#  (('call of duty', 'mario party'), 213367),
#  (('far cry', 'watch dogs'), 213209),
#  (('spiderman', 'super mario maker'), 213132),
#  (('grand theft auto', 'street fighter'), 213071),
#  (('super smash bros', 'the sims'), 213027),
#  (('five nights at freddys', 'red dead redemption'), 212981),
#  (('five nights at freddys', 'the last of us'), 212795),
#  (('final fantasy', 'league of legends'), 212174),
#  (('far cry', 'hitman'), 212173),
#  (('counterstrike', 'mortal kombat'), 211488),
#  (('assassins creed', 'hitman'), 211353),
#  (('fortnite', 'kingdom hearts'), 211289),
#  (('fifa 18', 'grand theft auto'), 211221),
#  (('far cry', 'the sims'), 210931),
#  (('super mario 64', 'the legend of zelda'), 210844),
#  (('minecraft', 'papers  please'), 210789),
#  (('crash bandicoot', 'five nights at freddys'), 210184),
#  (('dark souls', 'undertale'), 209990),
#  (('goat simulator', 'roblox'), 209979),
#  (('geometry dash', 'undertale'), 209968),
#  (('fallout 4', 'team fortress 2'), 209929),
#  (('grand theft auto', 'super mario odyssey'), 209760),
#  (('garrys mod', 'mario bros'), 209746),
#  (('minecraft', 'mirrors edge'), 209576),
#  (('happy wheels', 'skate 3'), 209212),
#  (('dragon ball xenoverse', 'grand theft auto'), 209187),
#  (('mortal kombat', 'street fighter'), 209146),
#  (('metroid', 'the legend of zelda'), 209004),
#  (('minecraft', 'sonic mania'), 208978),
#  (('fallout 4', 'undertale'), 208731),
#  (('borderlands 3', 'fortnite'), 208393),
#  (('far cry', 'roblox'), 208161),
#  (('dead island', 'minecraft'), 207940),
#  (('battlefield 4', 'battlefield v'), 207615),
#  (('grand theft auto', 'just cause 3'), 207241),
#  (('mega man', 'the legend of zelda'), 207117),
#  (('call of duty', 'halflife'), 207060),
#  (('destiny 2', 'fallout 4'), 207051),
#  (('grand theft auto', 'the escapists'), 207030),
#  (('life is strange', 'the sims'), 206952),
#  (('call of duty', 'silent hill'), 206945),
#  (('minecraft', 'payday 2'), 206870),
#  (('minecraft', 'the evil within'), 206810),
#  (('dark souls', 'world of warcraft'), 206756),
#  (('subnautica', 'yandere simulator'), 206309),
#  (('fortnite', 'goat simulator'), 206134),
#  (('resident evil', 'until dawn'), 206065),
#  (('battlefield 1', 'resident evil'), 206065),
#  (('call of duty', 'the witcher'), 205917),
#  (('crash bandicoot', 'grand theft auto'), 205666),
#  (('god of war', 'mortal kombat'), 205567),
#  (('garrys mod', 'vrchat'), 205501),
#  (('counterstrike', 'the sims'), 205386),
#  (('minecraft', 'plague inc evolved'), 205370),
#  (('grand theft auto', 'halo 4'), 205317),
#  (('five nights at freddys', 'pokémon go'), 205301),
#  (('assassins creed', 'fear'), 205180),
#  (('dark souls', 'red dead redemption'), 205166),
#  (('far cry', 'star wars battlefront'), 204960),
#  (('hello neighbor', 'spiderman'), 204529),
#  (('five nights at freddys', 'rocket league'), 204466),
#  (('halo 5 guardians', 'minecraft'), 204200),
#  (('detroit become human', 'resident evil'), 204190),
#  (('call of duty', 'goat simulator'), 203493),
#  (('grand theft auto', 'kingdom hearts'), 203275),
#  (('call of duty', 'mega man'), 203273),
#  (('call of duty', 'fallout 3'), 203007),
#  (('cities skylines', 'grand theft auto'), 202926),
#  (('assassins creed', 'destiny 2'), 202746),
#  (('fallout 4', 'hitman'), 202697),
#  (('ark survival evolved', 'fallout 4'), 202649),
#  (('huniepop', 'minecraft'), 202607),
#  (('call of duty', 'dota 2'), 202531),
#  (('final fantasy', 'kingdom hearts'), 202499),
#  (('grand theft auto', 'mario party'), 202367),
#  (('mortal kombat', 'super mario maker'), 202309),
#  (('call of duty', 'kerbal space program'), 202172),
#  (('angry birds', 'minecraft'), 202043),
#  (('counterstrike', 'undertale'), 201973),
#  (('final fantasy', 'five nights at freddys'), 201918),
#  (('god of war', 'red dead redemption'), 201750),
#  (('five nights at freddys', 'star wars battlefront'), 201420),
#  (('clash royale', 'counterstrike'), 201349),
#  (('five nights at freddys', 'tomodachi life'), 201340),
#  (('red dead redemption', 'roblox'), 201339),
#  (('minecraft', 'rollercoaster tycoon'), 201310),
#  (('happy wheels', 'mario bros'), 201217),
#  (('battlefield 4', 'fallout 4'), 201215),
#  (('mario bros', 'super mario 64'), 200871),
#  (('far cry', 'league of legends'), 200836),
#  (('fortnite', 'jump force'), 200644),
#  (('counterstrike', 'fear'), 200642),
#  (('bioshock', 'grand theft auto'), 200400),
#  (('resident evil', 'sonic the hedgehog'), 200183),
#  (('fallout 4', 'the legend of zelda'), 200161),
#  (('clash royale', 'league of legends'), 199987),
#  (('subnautica', 'totally accurate battle simulator'), 199759),
#  (('final fantasy', 'mortal kombat'), 199744),
#  (('fear', 'super smash bros'), 199627),
#  (('minecraft', 'superhot'), 199435),
#  (('five nights at freddys', 'mario party'), 199363),
#  (('assassins creed', 'battlefield v'), 199232),
#  (('gears of war', 'grand theft auto'), 199064),
#  (('dead by daylight', 'roblox'), 198991),
#  (('clash royale', 'garrys mod'), 198830),
#  (('dark souls', 'super mario maker'), 198795),
#  (('astroneer', 'minecraft'), 198721),
#  (('counterstrike', 'world of warcraft'), 198669),
#  (('minecraft', 'slender the arrival'), 198560),
#  (('minecraft', 'super mario world'), 198495),
#  (('battlefield 1', 'five nights at freddys'), 198180),
#  (('final fantasy', 'metal gear'), 198075),
#  (('splatoon', 'super mario maker'), 198025),
#  (('assassins creed', 'world of warcraft'), 197979),
#  (('donkey kong', 'the legend of zelda'), 197845),
#  (('mario kart 8', 'roblox'), 197716),
#  (('happy wheels', 'hitman'), 197714),
#  (('garrys mod', 'goat simulator'), 197568),
#  (('apex legends', 'roblox'), 197527),
#  (('league of legends', 'the legend of zelda'), 197419),
#  (('call of duty', 'donkey kong'), 197239),
#  (('mario kart 8', 'the legend of zelda'), 197238),
#  (('beyond two souls', 'grand theft auto'), 197217),
#  (('minecraft', 'the stanley parable'), 196961),
#  (('minecraft', 'octodad dadliest catch'), 196789),
#  (('donkey kong', 'fortnite'), 196728),
#  (('spiderman', 'subnautica'), 196712),
#  (('fear', 'league of legends'), 196584),
#  (('slitherio', 'the sims'), 196570),
#  (('call of duty', 'sea of thieves'), 196549),
#  (('garrys mod', 'the elder scrolls v skyrim'), 196472),
#  (('mortal kombat', 'the legend of zelda'), 196254),
#  (('counterstrike', 'spiderman'), 196038),
#  (('super smash bros', 'yandere simulator'), 195936),
#  (('mario bros', 'mario party'), 195879),
#  (('beat saber', 'fortnite'), 195823),
#  (('mario party', 'super mario maker'), 195726),
#  (('resident evil', 'yandere simulator'), 195535),
#  (('happy wheels', 'until dawn'), 195404),
#  (('counterstrike', 'rocket league'), 195256),
#  (('garrys mod', 'slitherio'), 194788),
#  (('splatoon', 'undertale'), 194708),
#  (('street fighter', 'super smash bros'), 194674),
#  (('counterstrike', 'star wars battlefront'), 194606),
#  (('bloodborne', 'call of duty'), 194479),
#  (('battlefield hardline', 'minecraft'), 194390),
#  (('dark souls', 'destiny 2'), 194212),
#  (('clash royale', 'happy wheels'), 193879),
#  (('forza horizon', 'need for speed'), 193872),
#  (('mario party', 'the legend of zelda'), 193818),
#  (('fortnite', 'left 4 dead'), 193628),
#  (('fortnite', 'tomb raider'), 193595),
#  (('fifa 14', 'fifa 17'), 193507),
#  (('fallout 4', 'final fantasy'), 193195),
#  (('garrys mod', 'portal 2'), 193117),
#  (('call of duty', 'crysis'), 193072),
#  (('fallout 4', 'fear'), 192552),
#  (('minecraft', 'pokémon omega ruby'), 192373),
#  (('fortnite', 'little nightmares'), 192322),
#  (('assassins creed', 'roblox'), 192303),
#  (('metal gear', 'super smash bros'), 192180),
#  (('battlefield 4', 'the last of us'), 192138),
#  (('minecraft', 'the walking dead the final season'), 192103),
#  (('fear', 'spiderman'), 192019),
#  (('dragon ball fighterz', 'fortnite'), 191806),
#  (('fortnite', 'tomodachi life'), 191804),
#  (('agario', 'the sims'), 191803),
#  (('battlefield hardline', 'grand theft auto'), 191799),
#  (('dark souls', 'fear'), 191671),
#  (('call of duty', 'friday the 13th the game'), 191387),
#  (('among us', 'garrys mod'), 191363),
#  (('fallout new vegas', 'grand theft auto'), 191200),
#  (('assassins creed', 'mass effect'), 191143),
#  (('fallout 4', 'no mans sky'), 190970),
#  (('call of duty', 'super mario 64'), 190478),
#  (('red dead redemption', 'star wars battlefront'), 190260),
#  (('hello neighbor', 'super mario maker'), 190209),
#  (('geometry dash', 'super mario maker'), 189951),
#  (('far cry', 'metal gear'), 189794),
#  (('garrys mod', 'geometry dash'), 189767),
#  (('call of duty', 'metroid'), 189426),
#  (('battlefield 4', 'league of legends'), 189377),
#  (('friday the 13th the game', 'grand theft auto'), 189250),
#  (('minecraft', 'the witcher'), 189041),
#  (('club penguin', 'fortnite'), 189031),
#  (('dragon ball fighterz', 'minecraft'), 188618),
#  (('infamous second son', 'minecraft'), 188561),
#  (('metal gear', 'mortal kombat'), 188153),
#  (('grand theft auto', 'iron man'), 188111),
#  (('call of duty', 'splatoon'), 188109),
#  (('hitman', 'roblox'), 188058),
#  (('fallout 4', 'watch dogs'), 187904),
#  (('roblox', 'skate 3'), 187740),
#  (('sonic the hedgehog', 'spiderman'), 187677),
#  (('resident evil', 'watch dogs'), 187665),
#  (('dead rising', 'fortnite'), 187540),
#  (('counterstrike', 'subnautica'), 187509),
#  (('kingdom hearts', 'the legend of zelda'), 187430),
#  (('call of duty', 'the escapists'), 187197),
#  (('spiderman', 'star wars battlefront'), 187063),
#  (('grand theft auto', 'silent hill'), 186631),
#  (('destiny 2', 'resident evil'), 186627),
#  (('fifa 19', 'grand theft auto'), 186576),
#  (('gang beasts', 'happy wheels'), 186486),
#  (('happy wheels', 'sonic the hedgehog'), 186461),
#  (('fortnite', 'super mario 64'), 186440),
#  (('battlefield v', 'far cry'), 186435),
#  (('minecraft', 'plague inc'), 186398),
#  (('beyond two souls', 'call of duty'), 186254),
#  (('dark souls', 'the last of us'), 186164),
#  (('call of duty', 'just cause 3'), 185984),
#  (('assassins creed', 'tomb raider'), 185706),
#  (('fortnite', 'the walking dead the final season'), 185603),
#  (('agario', 'clash royale'), 185564),
#  (('battlefield v', 'fallout 4'), 185538),
#  (('call of duty', 'dead island'), 185367),
#  (('agario', 'clash of clans'), 185311),
#  (('7 days to die', 'call of duty'), 185275),
#  (('garrys mod', 'plants vs zombies'), 185269),
#  (('far cry', 'god of war'), 185173),
#  (('fallout 3', 'fallout 4'), 185120),
#  (('counterstrike', 'hitman'), 185110),
#  (('league of legends', 'spiderman'), 185091),
#  (('fallout 4', 'the last of us'), 185048),
#  (('battlefield 4', 'happy wheels'), 184966),
#  (('battlefield 4', 'star wars battlefront'), 184787),
#  (('detroit become human', 'spiderman'), 184751),
#  (('far cry', 'fear'), 184467),
#  (('resident evil', 'star wars battlefront'), 184442),
#  (('assassins creed', 'fallout 76'), 184111),
#  (('fifa 19', 'fifa 20'), 184056),
#  (('fortnite', 'slime rancher'), 183941),
#  (('minecraft', 'monster hunter world'), 183844),
#  (('borderlands 2', 'grand theft auto'), 183784),
#  (('final fantasy', 'spiderman'), 183711),
#  (('crysis', 'minecraft'), 183647),
#  (('dark souls', 'team fortress 2'), 183614),
#  (('subnautica', 'super mario maker'), 183450),
#  (('goat simulator', 'happy wheels'), 183441),
#  (('fallout 76', 'resident evil'), 183426),
#  (('dead rising', 'garrys mod'), 183372),
#  (('far cry', 'subnautica'), 183319),
#  (('hello neighbor', 'totally accurate battle simulator'), 183229),
#  (('alien isolation', 'minecraft'), 183111),
#  (('doki doki literature club', 'the sims'), 182988),
#  (('super mario 64', 'super mario maker'), 182929),
#  (('red dead redemption', 'super smash bros'), 182774),
#  (('five nights at freddys', 'watch dogs'), 182768),
#  (('splatoon', 'super mario odyssey'), 182526),
#  (('donkey kong', 'mario bros'), 182514),
#  (('counterstrike', 'red dead redemption'), 182260),
#  (('battlefield 1', 'destiny 2'), 182255),
#  (('jump force', 'minecraft'), 182166),
#  (('call of duty', 'flappy bird'), 182118),
#  (('fear', 'mortal kombat'), 182116),
#  (('mortal kombat', 'sonic the hedgehog'), 181903),
#  (('fortnite', 'the elder scrolls v skyrim'), 181881),
#  (('deadpool', 'fortnite'), 181785),
#  (('happy wheels', 'portal 2'), 181719),
#  (('five nights at freddys', 'skate 3'), 181606),
#  ...]

# %%
edges_pldf = pl.DataFrame({
    'game1': [edge[0][0] for edge in sorted_edges],
    'game2': [edge[0][1] for edge in sorted_edges],
    'weight': [edge[1] for edge in sorted_edges]
})

# uncomment to save the edges
# edges_pldf.write_csv('../data/games_edges.csv')

# %%
# # Polars version (doesn't work on full dataset)

# comments_video_game = comments_df.join(joined_df.lazy(), left_on='video_id', right_on='display_id')
# comments_channels = comments_video_game.select([
#     pl.col('author'),
#     pl.col('video_game')
# ]).unique()

# counts_per_author = (
#     comments_game_df
#     .group_by("author")
#     .agg(pl.col("video_game").count().alias("count"))
#     .filter(pl.col("count") > 1)
# )

# comments_several_channels = comments_game_df.join(counts_per_author, on="author", how="inner").select(['author', 'video_game'])

# pairs = comments_several_channels.join(comments_several_channels, on="author", how="inner").filter(pl.col('video_game') < pl.col('video_game_right')).select(['video_game', 'video_game_right'])

# pairs_grouped = pairs.group_by(['video_game', 'video_game_right']).agg(pl.col('video_game').count().alias('weight')).sort('weight', descending=True)

# pairs_grouped.collect()

# %% [markdown]
# ### Weight adjustment and filtering

# %%
def adjust_weight(edges: pl.DataFrame, popularity: dict, threshold: int, alpha: float, beta: float = 1.0) -> dict:
    adjusted_edges = {}
    for edge in edges.iter_rows():
        game1, game2, weight = edge
        # Get the popularity of the games
        p1 = popularity[game1]
        p2 = popularity[game2]
        # Adjust the weight using the formula
        adjusted_weight = int((weight ** beta) * ((min(p1, p2) / max(p1, p2)) ** alpha))
        if adjusted_weight > threshold:
            adjusted_edges[(game1, game2)] = adjusted_weight
    return adjusted_edges

# %%
edges = pl.read_csv("../data/games_edges_all.csv")
popularity = dict(zip(games_count["video_game"], games_count["count"]))
alpha = 0.5
beta = 0.75
threshold = 5000

adjusted_edges = adjust_weight(edges, popularity, threshold, alpha, beta)


edges_dict = {}
for edge in edges.iter_rows():
    game1, game2, weight = edge
    edges_dict[(game1, game2)] = weight

unique_games = set()
for edge in adjusted_edges:
    unique_games.add(edge[0])
    unique_games.add(edge[1])
    
print(f'After filtering : {len(adjusted_edges)} edges and {len(unique_games)} nodes')

print(f'Before adjustment ({len(edges_dict)} edges)')
print(f'fortnite -> minecraft: {edges_dict[("fortnite", "minecraft")]}')
print(f'fifa 14 -> minecraft: {edges_dict[("fifa 14", "minecraft")]}')
print(f'fifa 14 -> fifa 15: {edges_dict[("fifa 14", "fifa 15")]}')

print(f'After adjustment ({len(adjusted_edges)} edges)')
print(f'fortnite -> minecraft: {adjusted_edges[("fortnite", "minecraft")]} if ("fortnite", "minecraft") in adjusted_edges else 0')
print(f'fifa 14 -> minecraft: {adjusted_edges[("fifa 14", "minecraft")] if ("fifa 14", "minecraft") in adjusted_edges else 0}')
print(f'fifa 14 -> fifa 15: {adjusted_edges[("fifa 14", "fifa 15")] if ("fifa 14", "fifa 15") in adjusted_edges else 0}')
# Out:
# After filtering : 916 edges and 119 nodes
# Before adjustment (540605 edges)
# fortnite -> minecraft: 8238018
# fifa 14 -> minecraft: 437157
# fifa 14 -> fifa 15: 433682
# After adjustment (916 edges)
# fortnite -> minecraft: 107912 if ("fortnite", "minecraft") in adjusted_edges else 0
# fifa 14 -> minecraft: 0
# fifa 14 -> fifa 15: 15747

# %%
import networkx as nx
import community as community_louvain  # Install via `pip install python-louvain`
import json

# Example input (edges list with weights after adjustment)

# Create graph
G = nx.Graph()
for (source, target), weight in adjusted_edges.items():
    G.add_edge(source, target, weight=weight)

# Create node_size which is the popularity of the game divided by 2000

# # Compute positions using Fruchterman-Reingold (spring layout)
positions = nx.forceatlas2_layout(G, max_iter=500, seed=42, dissuade_hubs=True, jitter_tolerance=0.6, gravity=50)

# Community detection using Louvain method
partition = community_louvain.best_partition(G, random_state=42)

# Prepare nodes and edges for JSON output
nodes = []
node_map = {}  # Maps node names to IDs
for i, (node, pos) in enumerate(positions.items()):
    node_map[node] = str(i)
    pop = popularity[node]
    nodes.append({
        "id": str(i),
        "name": node,
        "x": pos[0] * 1000,  # Scale positions for better visualization
        "y": pos[1] * 1000,
        "symbolSize": (pop / 2000) ** 0.5,  # Example: size proportional to degree
        "value": pop,
        "category": partition[node]
    })

edges = [
    {"source": node_map[source], "target": node_map[target]}
    for source, target in G.edges()
]

categories = [
    {"name": name}
    for name in set(partition.values())
]

# Output JSON
output = {
    "nodes": nodes,
    "edges": edges,
    "categories": categories
}

print(f'Number of nodes in the network: {len(nodes)}')
print(f'Number of edges in the network: {len(edges)}')
print(f'Number of communities in the network: {len(categories)}')

# Save to file
with open('../datastory/data/games_network.json', 'w') as f:
    json.dump(output, f, indent=2)
# Out:
# Number of nodes in the network: 119
# Number of edges in the network: 916
# Number of communities in the network: 5
